# %%
import pandas as pd 
import numpy as np
import matplotlib

# %%
data = pd.read_csv('Factbook_OECD.csv')

# %%
data.head(10)
# Out:
#             SUB                             Subject LOCATION    Country   YEA  \
# 0  PRODINCOM_G1                 GDP per hour worked      AUS  Australia  2011
# 1  PRODINCOM_G1                 GDP per hour worked      AUS  Australia  2012
# 2  PRODINCOM_G1                 GDP per hour worked      AUS  Australia  2013
# 3  PRODINCOM_G1                 GDP per hour worked      AUS  Australia  2014
# 4  PRODINCOM_G1                 GDP per hour worked      AUS  Australia  2015
# 5     AIRQTY_T1  CO? emissions from fuel combustion      AUS  Australia  2011
# 6     AIRQTY_T1  CO? emissions from fuel combustion      AUS  Australia  2012
# 7     AIRQTY_T1  CO? emissions from fuel combustion      AUS  Australia  2013
# 8     AIRQTY_T1  CO? emissions from fuel combustion      AUS  Australia  2014
# 9     AIRQTY_T1  CO? emissions from fuel combustion      AUS  Australia  2015
#
#    Year Unit Code       Unit  PowerCode Code PowerCode Reference Period Code  \
# ...

# %%
cols_null = data.isnull().sum()

# %%
cols_null
# Out:
# SUB                          0
# Subject                      0
# LOCATION                     0
# Country                      0
# YEA                          0
# Year                         0
# Unit Code                    0
# Unit                         0
# PowerCode Code               0
# PowerCode                    0
# Reference Period Code    34189
# Reference Period         34189
# Value                        0
# Flag Codes               34346
# Flags                    34346
# dtype: int64

# %%
drop_cols = list(cols_null[cols_null>30000].index)

# %%
drop_cols
# Out:
# ['Reference Period Code', 'Reference Period', 'Flag Codes', 'Flags']

# %%
data = data.drop(drop_cols, axis=1)

# %%
data
# Out:
#                 SUB                      Subject LOCATION    Country   YEA  \
# 0      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2011
# 1      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2012
# 2      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2013
# 3      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2014
# 4      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2015
# ...             ...                          ...      ...        ...   ...
# 35064     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2011
# 35065     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2012
# 35066     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2013
# 35067     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2014
# 35068     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2015
#
# ...
