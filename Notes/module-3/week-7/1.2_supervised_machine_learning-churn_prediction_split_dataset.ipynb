# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Splitting our dataset into train and test set

# %%
df = pd.read_pickle("data/clean_dataset.pkl")

# %%
df.shape
# Out:
# (7043, 21)

# %%
len(train_test_split(df, test_size=.2, random_state=17))
# Out:
# 2

# %%
train, test = train_test_split(df, test_size=.2, random_state=17)

# %%
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %%
train.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  9369-XFEHK  Female              1     Yes         No      33          Yes
# 1  3545-CNWRG  Female              0     Yes        Yes      49          Yes
# 2  0899-WZRSD    Male              0      No         No      56          Yes
# 3  1764-VUUMT    Male              0      No        Yes      66          Yes
# 4  2903-YYTBW    Male              0     Yes        Yes       1          Yes
#
#    MultipleLines InternetService  OnlineSecurity  ...  DeviceProtection  \
# 0              1     Fiber optic               0  ...                 0
# 1              1     Fiber optic               0  ...                 0
# 2              1     Fiber optic               1  ...                 0
# 3              0              No               0  ...                 0
# 4              0             DSL               0  ...                 0
#
# ...

# %%
test.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  8707-RMEZH  Female              1     Yes         No      69          Yes
# 1  1216-BGTSP    Male              0      No         No      45          Yes
# 2  5118-MUEYH  Female              0     Yes         No      48          Yes
# 3  4821-SJHJV  Female              0     Yes        Yes      32          Yes
# 4  8245-UMPYT  Female              1      No         No      16          Yes
#
#    MultipleLines InternetService  OnlineSecurity  ...  DeviceProtection  \
# 0              0     Fiber optic               1  ...                 0
# 1              1     Fiber optic               1  ...                 1
# 2              1     Fiber optic               0  ...                 0
# 3              1     Fiber optic               1  ...                 0
# 4              1     Fiber optic               0  ...                 0
#
# ...

# %%
train.to_pickle("data/train.pkl")
test.to_pickle("data/test.pkl")

# %% [markdown]
# ### Create alternative

# %%
def split_dataset(df, test_size=.2, random_state=17, save_as_pickle=True, file_suffix="banana"):
    train, test = train_test_split(df, test_size=test_size, random_state=random_state)
    train = train.reset_index(drop=True)
    test = test.reset_index(drop=True)
    if save_as_pickle:
        train.to_pickle(f"data/train_{file_suffix}.pkl")
        test.to_pickle(f"data/test_{file_suffix}.pkl")
        
    return train, test

# %%
split_dataset(df, random_state=20)
# Out:
# (      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
#  0     5140-FOMCQ  Female              0     Yes         No      59
#  1     8869-TORSS  Female              0      No         No      48
#  2     1583-IHQZE    Male              0      No         No      12
#  3     3957-LXOLK  Female              1      No         No      28
#  4     2933-FILNV  Female              0     Yes        Yes       2
#  ...          ...     ...            ...     ...        ...     ...
#  5629  3115-JPJDD  Female              0     Yes         No      59
#  5630  7767-UXAGJ    Male              0      No         No       1
#  5631  1444-VVSGW    Male              0     Yes         No      70
#  5632  3340-QBBFM    Male              1     Yes         No      36
#  5633  0661-KBKPA    Male              0     Yes        Yes      53
#
#       PhoneService  MultipleLines InternetService  OnlineSecurity  ...  \
#  0             Yes              1     Fiber optic               1  ...
# ...
