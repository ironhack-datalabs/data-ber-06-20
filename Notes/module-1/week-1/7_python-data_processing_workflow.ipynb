# %% [markdown]
# # Data Processing (Vanilla Python)

# %% [markdown]
# | street | city | ... |
# |--------|------|-----|
# | HIGH ST | SACRAMENTO | ... |
# | LOW ST | SACRAMENTO | ... |
# | ... | ... | ... |

# %%
{"street": ["HIGH ST", "LOW ST"],
 "city": ["SACRAMENTO", "SACRAMENTO"]}
# Out:
# {'street': ['HIGH ST', 'LOW ST'], 'city': ['SACRAMENTO', 'SACRAMENTO']}

# %%
{1: ["HIGH ST", "SACRAMENTO"],
 2: ["LOW ST", "SACRAMENTO"]}
# Out:
# {1: ['HIGH ST', 'SACRAMENTO'], 2: ['LOW ST', 'SACRAMENTO']}

# %%
{0: {"street": "HIGH ST",
       "city": "SACRAMENTO"},
 1: {"street": "LOW ST",
       "city": "SACRAMENTO"}}
# Out:
# {0: {'street': 'HIGH ST', 'city': 'SACRAMENTO'},
#  1: {'street': 'LOW ST', 'city': 'SACRAMENTO'}}

# %%
header = ["street", "city"]
data = [["HIGH ST", "SACRAMENTO"],
        ["LOW ST", "SACRAMENTO"]]

# %% [markdown]
# All of these are possible.
#
# We will use a `list` of `dict`s

# %%
data = [{"street": "HIGH ST",
         "city": "SACRAMENTO"},
        {"street": "LOW ST",
         "city": "SACRAMENTO"}]

# %%
data
# Out:
# [{'street': 'HIGH ST', 'city': 'SACRAMENTO'},
#  {'street': 'LOW ST', 'city': 'SACRAMENTO'}]

# %% [markdown]
# # 1. Read the data

# %%
import csv
with open("data/sacramento_data.csv", "r") as csvfile:
    reader = csv.DictReader(csvfile)
    
    for i, row in enumerate(reader):
        print(f"This is row number {i + 1}")
        print("========================")
        print(row)
# Out:
# This is row number 1
# ========================
# {'street': '3526 HIGH ST', 'city': 'SACRAMENTO', 'zip': '95838', 'state': 'CA', 'beds': '2', 'baths': '1', 'sq__ft': '836', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '59222', 'latitude': '38.631913', 'longitude': '-121.434879'}
# This is row number 2
# ========================
# {'street': '51 OMAHA CT', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '1167', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '68212', 'latitude': '38.478902', 'longitude': '-121.431028'}
# This is row number 3
# ========================
# {'street': '2796 BRANCH ST', 'city': 'SACRAMENTO', 'zip': '95815', 'state': 'CA', 'beds': '2', 'baths': '1', 'sq__ft': '796', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '68880', 'latitude': '38.618305', 'longitude': '-121.443839'}
# This is row number 4
# ========================
# {'street': '2805 JANETTE WAY', 'city': 'SACRAMENTO', 'zip': '95815', 'state': 'CA', 'beds': '2', 'baths': '1', 'sq__ft': '852', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '69307', 'latitude': '38.616835', 'longitude': '-121.439146'}
# This is row number 5
# ========================
# {'street': '6001 MCMAHON DR', 'city': 'SACRAMENTO', 'zip': '95824', 'state': 'CA', 'beds': '2', 'baths': '1', 'sq__ft': '797', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '81900', 'latitude': '38.51947', 'longitude': '-121.435768'}
# This is row number 6
# ========================
# {'street': '5828 PEPPERMILL CT', 'city': 'SACRAMENTO', 'zip': '95841', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '1122', 'type': 'Condo', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '89921', 'latitude': '38.662595', 'longitude': '-121.327813'}
# This is row number 7
# ========================
# {'street': '6048 OGDEN NASH WAY', 'city': 'SACRAMENTO', 'zip': '95842', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1104', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '90895', 'latitude': '38.681659', 'longitude': '-121.351705'}
# This is row number 8
# ========================
# {'street': '2561 19TH AVE', 'city': 'SACRAMENTO', 'zip': '95820', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '1177', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '91002', 'latitude': '38.535092', 'longitude': '-121.481367'}
# This is row number 9
# ========================
# {'street': '11150 TRINITY RIVER DR Unit 114', 'city': 'RANCHO CORDOVA', 'zip': '95670', 'state': 'CA', 'beds': '2', 'baths': '2', 'sq__ft': '941', 'type': 'Condo', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '94905', 'latitude': '38.621188', 'longitude': '-121.270555'}
# This is row number 10
# ========================
# {'street': '7325 10TH ST', 'city': 'RIO LINDA', 'zip': '95673', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1146', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '98937', 'latitude': '38.700909', 'longitude': '-121.442979'}
# This is row number 11
# ========================
# {'street': '645 MORRISON AVE', 'city': 'SACRAMENTO', 'zip': '95838', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '909', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '100309', 'latitude': '38.637663', 'longitude': '-121.45152'}
# This is row number 12
# ========================
# {'street': '4085 FAWN CIR', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1289', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '106250', 'latitude': '38.470746', 'longitude': '-121.458918'}
# This is row number 13
# ========================
# {'street': '2930 LA ROSA RD', 'city': 'SACRAMENTO', 'zip': '95815', 'state': 'CA', 'beds': '1', 'baths': '1', 'sq__ft': '871', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '106852', 'latitude': '38.618698', 'longitude': '-121.435833'}
# This is row number 14
# ========================
# {'street': '2113 KIRK WAY', 'city': 'SACRAMENTO', 'zip': '95822', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '1020', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '107502', 'latitude': '38.482215', 'longitude': '-121.492603'}
# This is row number 15
# ========================
# {'street': '4533 LOCH HAVEN WAY', 'city': 'SACRAMENTO', 'zip': '95842', 'state': 'CA', 'beds': '2', 'baths': '2', 'sq__ft': '1022', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '108750', 'latitude': '38.672914', 'longitude': '-121.35934'}
# This is row number 16
# ========================
# {'street': '7340 HAMDEN PL', 'city': 'SACRAMENTO', 'zip': '95842', 'state': 'CA', 'beds': '2', 'baths': '2', 'sq__ft': '1134', 'type': 'Condo', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '110700', 'latitude': '38.700051', 'longitude': '-121.351278'}
# This is row number 17
# ========================
# {'street': '6715 6TH ST', 'city': 'RIO LINDA', 'zip': '95673', 'state': 'CA', 'beds': '2', 'baths': '1', 'sq__ft': '844', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '113263', 'latitude': '38.689591', 'longitude': '-121.452239'}
# This is row number 18
# ========================
# {'street': '6236 LONGFORD DR Unit 1', 'city': 'CITRUS HEIGHTS', 'zip': '95621', 'state': 'CA', 'beds': '2', 'baths': '1', 'sq__ft': '795', 'type': 'Condo', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '116250', 'latitude': '38.679776', 'longitude': '-121.314089'}
# This is row number 19
# ========================
# {'street': '250 PERALTA AVE', 'city': 'SACRAMENTO', 'zip': '95833', 'state': 'CA', 'beds': '2', 'baths': '1', 'sq__ft': '588', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '120000', 'latitude': '38.612099', 'longitude': '-121.469095'}
# This is row number 20
# ========================
# {'street': '113 LEEWILL AVE', 'city': 'RIO LINDA', 'zip': '95673', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1356', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '121630', 'latitude': '38.689999', 'longitude': '-121.46322'}
# This is row number 21
# ========================
# {'street': '6118 STONEHAND AVE', 'city': 'CITRUS HEIGHTS', 'zip': '95621', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1118', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '122000', 'latitude': '38.707851', 'longitude': '-121.320707'}
# This is row number 22
# ========================
# {'street': '4882 BANDALIN WAY', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1329', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '122682', 'latitude': '38.468173', 'longitude': '-121.444071'}
# This is row number 23
# ========================
# {'street': '7511 OAKVALE CT', 'city': 'NORTH HIGHLANDS', 'zip': '95660', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1240', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '123000', 'latitude': '38.702792', 'longitude': '-121.38221'}
# This is row number 24
# ========================
# {'street': '9 PASTURE CT', 'city': 'SACRAMENTO', 'zip': '95834', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1601', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '124100', 'latitude': '38.628631', 'longitude': '-121.488097'}
# This is row number 25
# ========================
# {'street': '3729 BAINBRIDGE DR', 'city': 'NORTH HIGHLANDS', 'zip': '95660', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '901', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '125000', 'latitude': '38.701499', 'longitude': '-121.37622'}
# This is row number 26
# ========================
# {'street': '3828 BLACKFOOT WAY', 'city': 'ANTELOPE', 'zip': '95843', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1088', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '126640', 'latitude': '38.70974', 'longitude': '-121.37377'}
# This is row number 27
# ========================
# {'street': '4108 NORTON WAY', 'city': 'SACRAMENTO', 'zip': '95820', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '963', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '127281', 'latitude': '38.537526', 'longitude': '-121.478315'}
# This is row number 28
# ========================
# {'street': '1469 JANRICK AVE', 'city': 'SACRAMENTO', 'zip': '95832', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1119', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '129000', 'latitude': '38.476472', 'longitude': '-121.501711'}
# This is row number 29
# ========================
# {'street': '9861 CULP WAY', 'city': 'SACRAMENTO', 'zip': '95827', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1380', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '131200', 'latitude': '38.558423', 'longitude': '-121.327948'}
# This is row number 30
# ========================
# {'street': '7825 CREEK VALLEY CIR', 'city': 'SACRAMENTO', 'zip': '95828', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1248', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '132000', 'latitude': '38.472122', 'longitude': '-121.404199'}
# This is row number 31
# ========================
# {'street': '5201 LAGUNA OAKS DR Unit 140', 'city': 'ELK GROVE', 'zip': '95758', 'state': 'CA', 'beds': '2', 'baths': '2', 'sq__ft': '1039', 'type': 'Condo', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '133000', 'latitude': '38.423251', 'longitude': '-121.444489'}
# This is row number 32
# ========================
# {'street': '6768 MEDORA DR', 'city': 'NORTH HIGHLANDS', 'zip': '95660', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1152', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '134555', 'latitude': '38.691161', 'longitude': '-121.37192'}
# This is row number 33
# ========================
# {'street': '3100 EXPLORER DR', 'city': 'SACRAMENTO', 'zip': '95827', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1380', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '136500', 'latitude': '38.566663', 'longitude': '-121.332644'}
# This is row number 34
# ========================
# {'street': '7944 DOMINION WAY', 'city': 'ELVERTA', 'zip': '95626', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1116', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '138750', 'latitude': '38.713182', 'longitude': '-121.411227'}
# This is row number 35
# ========================
# {'street': '5201 LAGUNA OAKS DR Unit 162', 'city': 'ELK GROVE', 'zip': '95758', 'state': 'CA', 'beds': '2', 'baths': '2', 'sq__ft': '1039', 'type': 'Condo', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '141000', 'latitude': '38.423251', 'longitude': '-121.444489'}
# This is row number 36
# ========================
# {'street': '3920 SHINING STAR DR', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1418', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '146250', 'latitude': '38.48742', 'longitude': '-121.462459'}
# This is row number 37
# ========================
# {'street': '5031 CORVAIR ST', 'city': 'NORTH HIGHLANDS', 'zip': '95660', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1082', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '147308', 'latitude': '38.658246', 'longitude': '-121.375469'}
# This is row number 38
# ========================
# {'street': '7661 NIXOS WAY', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1472', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '148750', 'latitude': '38.479553', 'longitude': '-121.463317'}
# This is row number 39
# ========================
# {'street': '7044 CARTHY WAY', 'city': 'SACRAMENTO', 'zip': '95828', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1146', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '149593', 'latitude': '38.49857', 'longitude': '-121.420925'}
# This is row number 40
# ========================
# {'street': '2442 LARKSPUR LN', 'city': 'SACRAMENTO', 'zip': '95825', 'state': 'CA', 'beds': '1', 'baths': '1', 'sq__ft': '760', 'type': 'Condo', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '150000', 'latitude': '38.58514', 'longitude': '-121.403736'}
# This is row number 41
# ========================
# {'street': '4800 WESTLAKE PKWY Unit 2109', 'city': 'SACRAMENTO', 'zip': '95835', 'state': 'CA', 'beds': '2', 'baths': '2', 'sq__ft': '1304', 'type': 'Condo', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '152000', 'latitude': '38.658812', 'longitude': '-121.542345'}
# This is row number 42
# ========================
# {'street': '2178 63RD AVE', 'city': 'SACRAMENTO', 'zip': '95822', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1207', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '154000', 'latitude': '38.493955', 'longitude': '-121.48966'}
# This is row number 43
# ========================
# {'street': '8718 ELK WAY', 'city': 'ELK GROVE', 'zip': '95624', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1056', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '156896', 'latitude': '38.41653', 'longitude': '-121.379653'}
# This is row number 44
# ========================
# {'street': '5708 RIDGEPOINT DR', 'city': 'ANTELOPE', 'zip': '95843', 'state': 'CA', 'beds': '2', 'baths': '2', 'sq__ft': '1043', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '161250', 'latitude': '38.72027', 'longitude': '-121.331555'}
# This is row number 45
# ========================
# {'street': '7315 KOALA CT', 'city': 'NORTH HIGHLANDS', 'zip': '95660', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1587', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '161500', 'latitude': '38.699251', 'longitude': '-121.371414'}
# This is row number 46
# ========================
# {'street': '2622 ERIN DR', 'city': 'SACRAMENTO', 'zip': '95833', 'state': 'CA', 'beds': '4', 'baths': '1', 'sq__ft': '1120', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '164000', 'latitude': '38.613765', 'longitude': '-121.488694'}
# This is row number 47
# ========================
# {'street': '8421 SUNBLAZE WAY', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1580', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '165000', 'latitude': '38.450543', 'longitude': '-121.432538'}
# This is row number 48
# ========================
# {'street': '7420 ALIX PKWY', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '4', 'baths': '1', 'sq__ft': '1955', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '166357', 'latitude': '38.489405', 'longitude': '-121.452811'}
# This is row number 49
# ========================
# {'street': '3820 NATOMA WAY', 'city': 'SACRAMENTO', 'zip': '95838', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1656', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '166357', 'latitude': '38.636748', 'longitude': '-121.422159'}
# This is row number 50
# ========================
# {'street': '4431 GREEN TREE DR', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1477', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '168000', 'latitude': '38.499954', 'longitude': '-121.454469'}
# This is row number 51
# ========================
# {'street': '9417 SARA ST', 'city': 'ELK GROVE', 'zip': '95624', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1188', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '170000', 'latitude': '38.415518', 'longitude': '-121.370527'}
# This is row number 52
# ========================
# {'street': '8299 HALBRITE WAY', 'city': 'SACRAMENTO', 'zip': '95828', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1590', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '173000', 'latitude': '38.473814', 'longitude': '-121.4'}
# This is row number 53
# ========================
# {'street': '7223 KALLIE KAY LN', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1463', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '174250', 'latitude': '38.477553', 'longitude': '-121.419463'}
# This is row number 54
# ========================
# {'street': '8156 STEINBECK WAY', 'city': 'SACRAMENTO', 'zip': '95828', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1714', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '174313', 'latitude': '38.474853', 'longitude': '-121.406326'}
# This is row number 55
# ========================
# {'street': '7957 VALLEY GREEN DR', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1185', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '178480', 'latitude': '38.465184', 'longitude': '-121.434925'}
# This is row number 56
# ========================
# {'street': '1122 WILD POPPY CT', 'city': 'GALT', 'zip': '95632', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1406', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '178760', 'latitude': '38.287789', 'longitude': '-121.294715'}
# This is row number 57
# ========================
# {'street': '4520 BOMARK WAY', 'city': 'SACRAMENTO', 'zip': '95842', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1943', 'type': 'Multi-Family', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '179580', 'latitude': '38.665724', 'longitude': '-121.358576'}
# This is row number 58
# ========================
# {'street': '9012 KIEFER BLVD', 'city': 'SACRAMENTO', 'zip': '95826', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1172', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '181000', 'latitude': '38.547011', 'longitude': '-121.366217'}
# This is row number 59
# ========================
# {'street': '5332 SANDSTONE ST', 'city': 'CARMICHAEL', 'zip': '95608', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '1152', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '181872', 'latitude': '38.662105', 'longitude': '-121.313945'}
# This is row number 60
# ========================
# {'street': '5993 SAWYER CIR', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '4', 'baths': '3', 'sq__ft': '1851', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '182587', 'latitude': '38.4473', 'longitude': '-121.435218'}
# This is row number 61
# ========================
# {'street': '4844 CLYDEBANK WAY', 'city': 'ANTELOPE', 'zip': '95843', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1215', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '182716', 'latitude': '38.714609', 'longitude': '-121.347887'}
# This is row number 62
# ========================
# {'street': '306 CAMELLIA WAY', 'city': 'GALT', 'zip': '95632', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1130', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '182750', 'latitude': '38.260443', 'longitude': '-121.297864'}
# This is row number 63
# ========================
# {'street': '9021 MADISON AVE', 'city': 'ORANGEVALE', 'zip': '95662', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1603', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '183200', 'latitude': '38.664186', 'longitude': '-121.217511'}
# This is row number 64
# ========================
# {'street': '404 6TH ST', 'city': 'GALT', 'zip': '95632', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '1479', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '188741', 'latitude': '38.251808', 'longitude': '-121.302493'}
# This is row number 65
# ========================
# {'street': '8317 SUNNY CREEK WAY', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1420', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '189000', 'latitude': '38.459041', 'longitude': '-121.424644'}
# This is row number 66
# ========================
# {'street': '2617 BASS CT', 'city': 'SACRAMENTO', 'zip': '95826', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1280', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '192067', 'latitude': '38.560767', 'longitude': '-121.377471'}
# This is row number 67
# ========================
# {'street': '7005 TIANT WAY', 'city': 'ELK GROVE', 'zip': '95758', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1586', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '194000', 'latitude': '38.422811', 'longitude': '-121.423285'}
# This is row number 68
# ========================
# {'street': '7895 CABER WAY', 'city': 'ANTELOPE', 'zip': '95843', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1362', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '194818', 'latitude': '38.711279', 'longitude': '-121.393449'}
# This is row number 69
# ========================
# {'street': '7624 BOGEY CT', 'city': 'SACRAMENTO', 'zip': '95828', 'state': 'CA', 'beds': '4', 'baths': '4', 'sq__ft': '2162', 'type': 'Multi-Family', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '195000', 'latitude': '38.48009', 'longitude': '-121.415102'}
# This is row number 70
# ========================
# {'street': '6930 HAMPTON COVE WAY', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1266', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '198000', 'latitude': '38.44004', 'longitude': '-121.421012'}
# This is row number 71
# ========================
# {'street': '8708 MESA BROOK WAY', 'city': 'ELK GROVE', 'zip': '95624', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1715', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '199500', 'latitude': '38.44076', 'longitude': '-121.385792'}
# This is row number 72
# ========================
# {'street': '120 GRANT LN', 'city': 'FOLSOM', 'zip': '95630', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1820', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '200000', 'latitude': '38.687742', 'longitude': '-121.17104'}
# This is row number 73
# ========================
# {'street': '5907 ELLERSLEE DR', 'city': 'CARMICHAEL', 'zip': '95608', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '936', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '200000', 'latitude': '38.664468', 'longitude': '-121.32683'}
# This is row number 74
# ========================
# {'street': '17 SERASPI CT', 'city': 'SACRAMENTO', 'zip': '95834', 'state': 'CA', 'beds': '0', 'baths': '0', 'sq__ft': '0', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '206000', 'latitude': '38.631481', 'longitude': '-121.50188'}
# This is row number 75
# ========================
# {'street': '170 PENHOW CIR', 'city': 'SACRAMENTO', 'zip': '95834', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1511', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '208000', 'latitude': '38.653439', 'longitude': '-121.535169'}
# This is row number 76
# ========================
# {'street': '8345 STAR THISTLE WAY', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1590', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '212864', 'latitude': '38.454349', 'longitude': '-121.439239'}
# This is row number 77
# ========================
# {'street': '9080 FRESCA WAY', 'city': 'ELK GROVE', 'zip': '95758', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1596', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '221000', 'latitude': '38.427818', 'longitude': '-121.424026'}
# This is row number 78
# ========================
# {'street': '391 NATALINO CIR', 'city': 'SACRAMENTO', 'zip': '95835', 'state': 'CA', 'beds': '2', 'baths': '2', 'sq__ft': '1341', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '221000', 'latitude': '38.67307', 'longitude': '-121.506373'}
# This is row number 79
# ========================
# {'street': '8373 BLACKMAN WAY', 'city': 'ELK GROVE', 'zip': '95624', 'state': 'CA', 'beds': '5', 'baths': '3', 'sq__ft': '2136', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '223058', 'latitude': '38.435436', 'longitude': '-121.394536'}
# This is row number 80
# ========================
# {'street': '9837 CORTE DORADO CT', 'city': 'ELK GROVE', 'zip': '95624', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1616', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '227887', 'latitude': '38.400676', 'longitude': '-121.38101'}
# This is row number 81
# ========================
# {'street': '5037 J PKWY', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1478', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '231477', 'latitude': '38.491399', 'longitude': '-121.443547'}
# This is row number 82
# ========================
# {'street': '10245 LOS PALOS DR', 'city': 'RANCHO CORDOVA', 'zip': '95670', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1287', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '234697', 'latitude': '38.593699', 'longitude': '-121.31089'}
# This is row number 83
# ========================
# {'street': '6613 NAVION DR', 'city': 'CITRUS HEIGHTS', 'zip': '95621', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1277', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '235000', 'latitude': '38.702855', 'longitude': '-121.31308'}
# This is row number 84
# ========================
# {'street': '2887 AZEVEDO DR', 'city': 'SACRAMENTO', 'zip': '95833', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1448', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '236000', 'latitude': '38.618457', 'longitude': '-121.509439'}
# This is row number 85
# ========================
# {'street': '9186 KINBRACE CT', 'city': 'SACRAMENTO', 'zip': '95829', 'state': 'CA', 'beds': '4', 'baths': '3', 'sq__ft': '2235', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '236685', 'latitude': '38.463355', 'longitude': '-121.358936'}
# This is row number 86
# ========================
# {'street': '4243 MIDDLEBURY WAY', 'city': 'MATHER', 'zip': '95655', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '2093', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '237800', 'latitude': '38.547991', 'longitude': '-121.280483'}
# This is row number 87
# ========================
# {'street': '1028 FALLON PLACE CT', 'city': 'RIO LINDA', 'zip': '95673', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1193', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '240122', 'latitude': '38.693818', 'longitude': '-121.441153'}
# This is row number 88
# ========================
# {'street': '4804 NORIKER DR', 'city': 'ELK GROVE', 'zip': '95757', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '2163', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '242638', 'latitude': '38.400974', 'longitude': '-121.448424'}
# This is row number 89
# ========================
# {'street': '7713 HARVEST WOODS DR', 'city': 'SACRAMENTO', 'zip': '95828', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1269', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '244000', 'latitude': '38.478198', 'longitude': '-121.412911'}
# This is row number 90
# ========================
# {'street': '2866 KARITSA AVE', 'city': 'SACRAMENTO', 'zip': '95833', 'state': 'CA', 'beds': '0', 'baths': '0', 'sq__ft': '0', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '244500', 'latitude': '38.626671', 'longitude': '-121.52597'}
# This is row number 91
# ========================
# {'street': '6913 RICHEVE WAY', 'city': 'SACRAMENTO', 'zip': '95828', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '958', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '244960', 'latitude': '38.502519', 'longitude': '-121.420769'}
# This is row number 92
# ========================
# {'street': '8636 TEGEA WAY', 'city': 'ELK GROVE', 'zip': '95624', 'state': 'CA', 'beds': '5', 'baths': '3', 'sq__ft': '2508', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '245918', 'latitude': '38.443832', 'longitude': '-121.382087'}
# This is row number 93
# ========================
# {'street': '5448 MAIDSTONE WAY', 'city': 'CITRUS HEIGHTS', 'zip': '95621', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1305', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '250000', 'latitude': '38.665395', 'longitude': '-121.293288'}
# This is row number 94
# ========================
# {'street': '18 OLLIE CT', 'city': 'ELK GROVE', 'zip': '95758', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1591', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '250000', 'latitude': '38.444909', 'longitude': '-121.412345'}
# This is row number 95
# ========================
# {'street': '4010 ALEX LN', 'city': 'CARMICHAEL', 'zip': '95608', 'state': 'CA', 'beds': '2', 'baths': '2', 'sq__ft': '1326', 'type': 'Condo', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '250134', 'latitude': '38.637028', 'longitude': '-121.312963'}
# This is row number 96
# ========================
# {'street': '4901 MILLNER WAY', 'city': 'ELK GROVE', 'zip': '95757', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1843', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '254200', 'latitude': '38.38692', 'longitude': '-121.447349'}
# This is row number 97
# ========================
# {'street': '4818 BRITTNEY LEE CT', 'city': 'SACRAMENTO', 'zip': '95841', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1921', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '254200', 'latitude': '38.653917', 'longitude': '-121.34218'}
# This is row number 98
# ========================
# {'street': '5529 LAGUNA PARK DR', 'city': 'ELK GROVE', 'zip': '95758', 'state': 'CA', 'beds': '5', 'baths': '3', 'sq__ft': '2790', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '258000', 'latitude': '38.42568', 'longitude': '-121.438062'}
# This is row number 99
# ========================
# {'street': '230 CANDELA CIR', 'city': 'SACRAMENTO', 'zip': '95835', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1541', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '260000', 'latitude': '38.656251', 'longitude': '-121.547572'}
# This is row number 100
# ========================
# {'street': '4900 71ST ST', 'city': 'SACRAMENTO', 'zip': '95820', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '1018', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '260014', 'latitude': '38.53151', 'longitude': '-121.421089'}
# This is row number 101
# ========================
# {'street': '12209 CONSERVANCY WAY', 'city': 'RANCHO CORDOVA', 'zip': '95742', 'state': 'CA', 'beds': '0', 'baths': '0', 'sq__ft': '0', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '263500', 'latitude': '38.553867', 'longitude': '-121.219141'}
# This is row number 102
# ========================
# {'street': '4236 NATOMAS CENTRAL DR', 'city': 'SACRAMENTO', 'zip': '95834', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1672', 'type': 'Condo', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '265000', 'latitude': '38.648879', 'longitude': '-121.544023'}
# This is row number 103
# ========================
# {'street': '5615 LUPIN LN', 'city': 'POLLOCK PINES', 'zip': '95726', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1380', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '265000', 'latitude': '38.708315', 'longitude': '-120.603872'}
# This is row number 104
# ========================
# {'street': '5625 JAMES WAY', 'city': 'SACRAMENTO', 'zip': '95822', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '975', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '271742', 'latitude': '38.523947', 'longitude': '-121.484946'}
# This is row number 105
# ========================
# {'street': '7842 LAHONTAN CT', 'city': 'SACRAMENTO', 'zip': '95829', 'state': 'CA', 'beds': '4', 'baths': '3', 'sq__ft': '2372', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '273750', 'latitude': '38.472976', 'longitude': '-121.318633'}
# This is row number 106
# ========================
# {'street': '6850 21ST ST', 'city': 'SACRAMENTO', 'zip': '95822', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1446', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '275086', 'latitude': '38.502194', 'longitude': '-121.490795'}
# This is row number 107
# ========================
# {'street': '2900 BLAIR RD', 'city': 'POLLOCK PINES', 'zip': '95726', 'state': 'CA', 'beds': '2', 'baths': '2', 'sq__ft': '1284', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '280908', 'latitude': '38.75485', 'longitude': '-120.60476'}
# This is row number 108
# ========================
# {'street': '2064 EXPEDITION WAY', 'city': 'SACRAMENTO', 'zip': '95832', 'state': 'CA', 'beds': '4', 'baths': '3', 'sq__ft': '3009', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '280987', 'latitude': '38.474099', 'longitude': '-121.490711'}
# This is row number 109
# ========================
# {'street': '2912 NORCADE CIR', 'city': 'SACRAMENTO', 'zip': '95826', 'state': 'CA', 'beds': '8', 'baths': '4', 'sq__ft': '3612', 'type': 'Multi-Family', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '282400', 'latitude': '38.559505', 'longitude': '-121.364839'}
# This is row number 110
# ========================
# {'street': '9507 SEA CLIFF WAY', 'city': 'ELK GROVE', 'zip': '95758', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '2056', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '285000', 'latitude': '38.410992', 'longitude': '-121.479043'}
# This is row number 111
# ========================
# {'street': '8882 AUTUMN GOLD CT', 'city': 'ELK GROVE', 'zip': '95624', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1993', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '287417', 'latitude': '38.4439', 'longitude': '-121.37255'}
# This is row number 112
# ========================
# {'street': '5322 WHITE LOTUS WAY', 'city': 'ELK GROVE', 'zip': '95757', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1857', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '291000', 'latitude': '38.391538', 'longitude': '-121.442596'}
# This is row number 113
# ========================
# {'street': '1838 CASTRO WAY', 'city': 'SACRAMENTO', 'zip': '95818', 'state': 'CA', 'beds': '2', 'baths': '1', 'sq__ft': '1126', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '292024', 'latitude': '38.556098', 'longitude': '-121.490787'}
# This is row number 114
# ========================
# {'street': '10158 CRAWFORD WAY', 'city': 'SACRAMENTO', 'zip': '95827', 'state': 'CA', 'beds': '4', 'baths': '4', 'sq__ft': '2213', 'type': 'Multi-Family', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '297000', 'latitude': '38.5703', 'longitude': '-121.315735'}
# This is row number 115
# ========================
# {'street': '7731 MASTERS ST', 'city': 'ELK GROVE', 'zip': '95758', 'state': 'CA', 'beds': '5', 'baths': '3', 'sq__ft': '2494', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '297000', 'latitude': '38.442031', 'longitude': '-121.410873'}
# This is row number 116
# ========================
# {'street': '4925 PERCHERON DR', 'city': 'ELK GROVE', 'zip': '95757', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1843', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '298000', 'latitude': '38.40154', 'longitude': '-121.447649'}
# This is row number 117
# ========================
# {'street': '2010 PROMONTORY POINT LN', 'city': 'GOLD RIVER', 'zip': '95670', 'state': 'CA', 'beds': '2', 'baths': '2', 'sq__ft': '1520', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '299000', 'latitude': '38.62869', 'longitude': '-121.261669'}
# This is row number 118
# ========================
# {'street': '4727 SAVOIE WAY', 'city': 'SACRAMENTO', 'zip': '95835', 'state': 'CA', 'beds': '5', 'baths': '3', 'sq__ft': '2800', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '304037', 'latitude': '38.658182', 'longitude': '-121.549521'}
# This is row number 119
# ========================
# {'street': '8664 MAGNOLIA HILL WAY', 'city': 'ELK GROVE', 'zip': '95624', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '2309', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '311000', 'latitude': '38.442352', 'longitude': '-121.389675'}
# This is row number 120
# ========================
# {'street': '9570 HARVEST ROSE WAY', 'city': 'SACRAMENTO', 'zip': '95827', 'state': 'CA', 'beds': '5', 'baths': '3', 'sq__ft': '2367', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '315537', 'latitude': '38.555993', 'longitude': '-121.340352'}
# This is row number 121
# ========================
# {'street': '4359 CREGAN CT', 'city': 'RANCHO CORDOVA', 'zip': '95742', 'state': 'CA', 'beds': '5', 'baths': '4', 'sq__ft': '3516', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '320000', 'latitude': '38.545128', 'longitude': '-121.224922'}
# This is row number 122
# ========================
# {'street': '5337 DUSTY ROSE WAY', 'city': 'RANCHO CORDOVA', 'zip': '95742', 'state': 'CA', 'beds': '0', 'baths': '0', 'sq__ft': '0', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '320000', 'latitude': '38.528575', 'longitude': '-121.2286'}
# This is row number 123
# ========================
# {'street': '8929 SUTTERS GOLD DR', 'city': 'SACRAMENTO', 'zip': '95826', 'state': 'CA', 'beds': '4', 'baths': '3', 'sq__ft': '1914', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '328360', 'latitude': '38.550848', 'longitude': '-121.370224'}
# This is row number 124
# ========================
# {'street': '8025 PEERLESS AVE', 'city': 'ORANGEVALE', 'zip': '95662', 'state': 'CA', 'beds': '2', 'baths': '1', 'sq__ft': '1690', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '334150', 'latitude': '38.71147', 'longitude': '-121.216214'}
# This is row number 125
# ========================
# {'street': '4620 WELERA WAY', 'city': 'ELK GROVE', 'zip': '95757', 'state': 'CA', 'beds': '3', 'baths': '3', 'sq__ft': '2725', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '335750', 'latitude': '38.398609', 'longitude': '-121.450148'}
# This is row number 126
# ========================
# {'street': '9723 TERRAPIN CT', 'city': 'ELK GROVE', 'zip': '95757', 'state': 'CA', 'beds': '4', 'baths': '3', 'sq__ft': '2354', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '335750', 'latitude': '38.403492', 'longitude': '-121.430224'}
# This is row number 127
# ========================
# {'street': '2115 SMOKESTACK WAY', 'city': 'SACRAMENTO', 'zip': '95833', 'state': 'CA', 'beds': '0', 'baths': '0', 'sq__ft': '0', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '339500', 'latitude': '38.602416', 'longitude': '-121.542965'}
# This is row number 128
# ========================
# {'street': '100 REBECCA WAY', 'city': 'FOLSOM', 'zip': '95630', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '2185', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '344250', 'latitude': '38.68479', 'longitude': '-121.149199'}
# This is row number 129
# ========================
# {'street': '9488 OAK VILLAGE WAY', 'city': 'ELK GROVE', 'zip': '95758', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1801', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '346210', 'latitude': '38.41333', 'longitude': '-121.404999'}
# This is row number 130
# ========================
# {'street': '8495 DARTFORD DR', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '3', 'baths': '3', 'sq__ft': '1961', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '347029', 'latitude': '38.448507', 'longitude': '-121.421346'}
# This is row number 131
# ========================
# {'street': '6708 PONTA DO SOL WAY', 'city': 'ELK GROVE', 'zip': '95757', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '3134', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '347650', 'latitude': '38.380635', 'longitude': '-121.425538'}
# This is row number 132
# ========================
# {'street': '4143 SEA MEADOW WAY', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '4', 'baths': '3', 'sq__ft': '1915', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '351300', 'latitude': '38.46534', 'longitude': '-121.457519'}
# This is row number 133
# ========================
# {'street': '3020 RICHARDSON CIR', 'city': 'EL DORADO HILLS', 'zip': '95762', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '0', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '352000', 'latitude': '38.691299', 'longitude': '-121.081752'}
# This is row number 134
# ========================
# {'street': '8082 LINDA ISLE LN', 'city': 'SACRAMENTO', 'zip': '95831', 'state': 'CA', 'beds': '0', 'baths': '0', 'sq__ft': '0', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '370000', 'latitude': '38.4772', 'longitude': '-121.5215'}
# This is row number 135
# ========================
# {'street': '15300 MURIETA SOUTH PKWY', 'city': 'RANCHO MURIETA', 'zip': '95683', 'state': 'CA', 'beds': '4', 'baths': '3', 'sq__ft': '2734', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '370500', 'latitude': '38.4874', 'longitude': '-121.075129'}
# This is row number 136
# ========================
# {'street': '11215 SHARRMONT CT', 'city': 'WILTON', 'zip': '95693', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '2110', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '372000', 'latitude': '38.35062', 'longitude': '-121.228349'}
# This is row number 137
# ========================
# {'street': '7105 DANBERG WAY', 'city': 'ELK GROVE', 'zip': '95757', 'state': 'CA', 'beds': '5', 'baths': '3', 'sq__ft': '3164', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '375000', 'latitude': '38.4019', 'longitude': '-121.420388'}
# This is row number 138
# ========================
# {'street': '5579 JERRY LITELL WAY', 'city': 'SACRAMENTO', 'zip': '95835', 'state': 'CA', 'beds': '5', 'baths': '3', 'sq__ft': '3599', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '381300', 'latitude': '38.677126', 'longitude': '-121.500519'}
# This is row number 139
# ========================
# {'street': '1050 FOXHALL WAY', 'city': 'SACRAMENTO', 'zip': '95831', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '2054', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '381942', 'latitude': '38.509819', 'longitude': '-121.519661'}
# This is row number 140
# ========================
# {'street': '7837 ABBINGTON WAY', 'city': 'ANTELOPE', 'zip': '95843', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1830', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '387731', 'latitude': '38.709873', 'longitude': '-121.339472'}
# This is row number 141
# ========================
# {'street': '1300 F ST', 'city': 'SACRAMENTO', 'zip': '95814', 'state': 'CA', 'beds': '3', 'baths': '3', 'sq__ft': '1627', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '391000', 'latitude': '38.58355', 'longitude': '-121.487289'}
# This is row number 142
# ========================
# {'street': '6801 RAWLEY WAY', 'city': 'ELK GROVE', 'zip': '95757', 'state': 'CA', 'beds': '4', 'baths': '3', 'sq__ft': '3440', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '394470', 'latitude': '38.408351', 'longitude': '-121.423925'}
# This is row number 143
# ========================
# {'street': '1693 SHELTER COVE DR', 'city': 'GREENWOOD', 'zip': '95635', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '2846', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '395000', 'latitude': '38.945357', 'longitude': '-120.908822'}
# This is row number 144
# ========================
# {'street': '9361 WADDELL LN', 'city': 'ELK GROVE', 'zip': '95624', 'state': 'CA', 'beds': '4', 'baths': '3', 'sq__ft': '2359', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '400186', 'latitude': '38.450829', 'longitude': '-121.349928'}
# This is row number 145
# ========================
# {'street': '10 SEA FOAM CT', 'city': 'SACRAMENTO', 'zip': '95831', 'state': 'CA', 'beds': '3', 'baths': '3', 'sq__ft': '2052', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '415000', 'latitude': '38.487885', 'longitude': '-121.545947'}
# This is row number 146
# ========================
# {'street': '6945 RIO TEJO WAY', 'city': 'ELK GROVE', 'zip': '95757', 'state': 'CA', 'beds': '5', 'baths': '3', 'sq__ft': '3433', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '425000', 'latitude': '38.385638', 'longitude': '-121.422616'}
# This is row number 147
# ========================
# {'street': '4186 TULIP PARK WAY', 'city': 'RANCHO CORDOVA', 'zip': '95742', 'state': 'CA', 'beds': '5', 'baths': '3', 'sq__ft': '3615', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '430000', 'latitude': '38.550617', 'longitude': '-121.23526'}
# This is row number 148
# ========================
# {'street': '9278 DAIRY CT', 'city': 'ELK GROVE', 'zip': '95624', 'state': 'CA', 'beds': '0', 'baths': '0', 'sq__ft': '0', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '445000', 'latitude': '38.420338', 'longitude': '-121.363757'}
# This is row number 149
# ========================
# {'street': '207 ORANGE BLOSSOM CIR Unit C', 'city': 'FOLSOM', 'zip': '95630', 'state': 'CA', 'beds': '5', 'baths': '3', 'sq__ft': '2687', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '460000', 'latitude': '38.646273', 'longitude': '-121.175322'}
# This is row number 150
# ========================
# {'street': '6507 RIO DE ONAR WAY', 'city': 'ELK GROVE', 'zip': '95757', 'state': 'CA', 'beds': '4', 'baths': '3', 'sq__ft': '2724', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '461000', 'latitude': '38.38253', 'longitude': '-121.428007'}
# This is row number 151
# ========================
# {'street': '7004 RAWLEY WAY', 'city': 'ELK GROVE', 'zip': '95757', 'state': 'CA', 'beds': '4', 'baths': '3', 'sq__ft': '3440', 'type': 'Residential', 'sale_date': 'Wed May 21 00:00:00 EDT 2008', 'price': '489332', 'latitude': '38.406421', 'longitude': '-121.422081'}
# This is row number 152
# ========================
# ...
# This is row number 936
# ========================
# {'street': '1080 RIO NORTE WAY', 'city': 'SACRAMENTO', 'zip': '95834', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1428', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '188700', 'latitude': '38.634335', 'longitude': '-121.486098'}
# This is row number 937
# ========================
# {'street': '5501 VALLETTA WAY', 'city': 'SACRAMENTO', 'zip': '95820', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '1039', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '189000', 'latitude': '38.530144', 'longitude': '-121.43749'}
# This is row number 938
# ========================
# {'street': '5624 MEMORY LN', 'city': 'FAIR OAKS', 'zip': '95628', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '1529', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '189000', 'latitude': '38.66745', 'longitude': '-121.2364'}
# This is row number 939
# ========================
# {'street': '6622 WILLOWLEAF DR', 'city': 'CITRUS HEIGHTS', 'zip': '95621', 'state': 'CA', 'beds': '4', 'baths': '3', 'sq__ft': '1892', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '189836', 'latitude': '38.699714', 'longitude': '-121.311635'}
# This is row number 940
# ========================
# {'street': '27 MEGAN CT', 'city': 'SACRAMENTO', 'zip': '95838', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1887', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '190000', 'latitude': '38.649258', 'longitude': '-121.465308'}
# This is row number 941
# ========================
# {'street': '6601 WOODMORE OAKS DR', 'city': 'ORANGEVALE', 'zip': '95662', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1294', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '191250', 'latitude': '38.687006', 'longitude': '-121.254319'}
# This is row number 942
# ========================
# {'street': '1973 DANVERS WAY', 'city': 'SACRAMENTO', 'zip': '95832', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1638', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '191675', 'latitude': '38.477568', 'longitude': '-121.492574'}
# This is row number 943
# ========================
# {'street': '8001 ARROYO VISTA DR', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1677', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '195500', 'latitude': '38.46734', 'longitude': '-121.419843'}
# This is row number 944
# ========================
# {'street': '7409 VOYAGER WAY', 'city': 'CITRUS HEIGHTS', 'zip': '95621', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '1073', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '198000', 'latitude': '38.700717', 'longitude': '-121.3133'}
# This is row number 945
# ========================
# {'street': '815 CROSSWIND DR', 'city': 'SACRAMENTO', 'zip': '95838', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1231', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '200000', 'latitude': '38.651386', 'longitude': '-121.45042'}
# This is row number 946
# ========================
# {'street': '5509 LAGUNA CREST WAY', 'city': 'ELK GROVE', 'zip': '95758', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1175', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '200000', 'latitude': '38.42442', 'longitude': '-121.440357'}
# This is row number 947
# ========================
# {'street': '8424 MERRY HILL WAY', 'city': 'ELK GROVE', 'zip': '95624', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1416', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '200000', 'latitude': '38.452075', 'longitude': '-121.366461'}
# This is row number 948
# ========================
# {'street': '1525 PENNSYLVANIA AVE', 'city': 'WEST SACRAMENTO', 'zip': '95691', 'state': 'CA', 'beds': '0', 'baths': '0', 'sq__ft': '0', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '200100', 'latitude': '38.569943', 'longitude': '-121.527539'}
# This is row number 949
# ========================
# {'street': '5954 BRIDGECROSS DR', 'city': 'SACRAMENTO', 'zip': '95835', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1358', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '201528', 'latitude': '38.68197', 'longitude': '-121.500025'}
# This is row number 950
# ========================
# {'street': '8789 SEQUOIA WOOD CT', 'city': 'ELK GROVE', 'zip': '95624', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1609', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '204750', 'latitude': '38.438818', 'longitude': '-121.37443'}
# This is row number 951
# ========================
# {'street': '6600 SILVERTHORNE CIR', 'city': 'SACRAMENTO', 'zip': '95842', 'state': 'CA', 'beds': '4', 'baths': '3', 'sq__ft': '1968', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '205000', 'latitude': '38.68607', 'longitude': '-121.342369'}
# This is row number 952
# ========================
# {'street': '2221 2ND AVE', 'city': 'SACRAMENTO', 'zip': '95818', 'state': 'CA', 'beds': '2', 'baths': '2', 'sq__ft': '1089', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '205000', 'latitude': '38.555781', 'longitude': '-121.485331'}
# This is row number 953
# ========================
# {'street': '3230 SMATHERS WAY', 'city': 'CARMICHAEL', 'zip': '95608', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1296', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '205900', 'latitude': '38.623372', 'longitude': '-121.347665'}
# This is row number 954
# ========================
# {'street': '5209 LAGUNA CREST WAY', 'city': 'ELK GROVE', 'zip': '95758', 'state': 'CA', 'beds': '2', 'baths': '2', 'sq__ft': '1189', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '207000', 'latitude': '38.424421', 'longitude': '-121.443915'}
# This is row number 955
# ========================
# {'street': '416 LEITCH AVE', 'city': 'SACRAMENTO', 'zip': '95815', 'state': 'CA', 'beds': '2', 'baths': '1', 'sq__ft': '795', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '207973', 'latitude': '38.612694', 'longitude': '-121.456669'}
# This is row number 956
# ========================
# {'street': '2100 BEATTY WAY', 'city': 'ROSEVILLE', 'zip': '95747', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1371', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '208250', 'latitude': '38.737882', 'longitude': '-121.308142'}
# This is row number 957
# ========================
# {'street': '6920 GILLINGHAM WAY', 'city': 'NORTH HIGHLANDS', 'zip': '95660', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '1310', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '208318', 'latitude': '38.694279', 'longitude': '-121.373395'}
# This is row number 958
# ========================
# {'street': '82 WILDFLOWER DR', 'city': 'GALT', 'zip': '95632', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1262', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '209347', 'latitude': '38.259708', 'longitude': '-121.311616'}
# This is row number 959
# ========================
# {'street': '8652 BANTON CIR', 'city': 'ELK GROVE', 'zip': '95624', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1740', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '211500', 'latitude': '38.444', 'longitude': '-121.370993'}
# This is row number 960
# ========================
# {'street': '8428 MISTY PASS WAY', 'city': 'ANTELOPE', 'zip': '95843', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1517', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '212000', 'latitude': '38.722959', 'longitude': '-121.347115'}
# This is row number 961
# ========================
# {'street': '7958 ROSEVIEW WAY', 'city': 'SACRAMENTO', 'zip': '95828', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1450', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '213000', 'latitude': '38.467836', 'longitude': '-121.410366'}
# This is row number 962
# ========================
# {'street': '9020 LUKEN CT', 'city': 'ELK GROVE', 'zip': '95624', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1416', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '216000', 'latitude': '38.451398', 'longitude': '-121.366614'}
# This is row number 963
# ========================
# {'street': '7809 VALLECITOS WAY', 'city': 'SACRAMENTO', 'zip': '95828', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '888', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '216021', 'latitude': '38.508217', 'longitude': '-121.411207'}
# This is row number 964
# ========================
# {'street': '8445 OLD AUBURN RD', 'city': 'CITRUS HEIGHTS', 'zip': '95610', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1882', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '219000', 'latitude': '38.715423', 'longitude': '-121.246743'}
# This is row number 965
# ========================
# {'street': '10085 ATKINS DR', 'city': 'ELK GROVE', 'zip': '95757', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1302', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '219794', 'latitude': '38.390893', 'longitude': '-121.437821'}
# This is row number 966
# ========================
# {'street': '9185 CERROLINDA CIR', 'city': 'ELK GROVE', 'zip': '95758', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1418', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '220000', 'latitude': '38.424497', 'longitude': '-121.426595'}
# This is row number 967
# ========================
# {'street': '9197 CORTINA CIR', 'city': 'ROSEVILLE', 'zip': '95678', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '0', 'type': 'Condo', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '220000', 'latitude': '38.793152', 'longitude': '-121.290025'}
# This is row number 968
# ========================
# {'street': '5429 HESPER WAY', 'city': 'CARMICHAEL', 'zip': '95608', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1319', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '220000', 'latitude': '38.665104', 'longitude': '-121.315901'}
# This is row number 969
# ========================
# {'street': '1178 WARMWOOD CT', 'city': 'GALT', 'zip': '95632', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1770', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '220000', 'latitude': '38.289544', 'longitude': '-121.284607'}
# This is row number 970
# ========================
# {'street': '4900 ELUDE CT', 'city': 'SACRAMENTO', 'zip': '95842', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1627', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '223000', 'latitude': '38.69674', 'longitude': '-121.350519'}
# This is row number 971
# ========================
# {'street': '3557 SODA WAY', 'city': 'SACRAMENTO', 'zip': '95834', 'state': 'CA', 'beds': '0', 'baths': '0', 'sq__ft': '0', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '224000', 'latitude': '38.631026', 'longitude': '-121.501879'}
# This is row number 972
# ========================
# {'street': '3528 SAINT GEORGE DR', 'city': 'SACRAMENTO', 'zip': '95821', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '1040', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '224000', 'latitude': '38.629468', 'longitude': '-121.376445'}
# This is row number 973
# ========================
# {'street': '7381 WASHBURN WAY', 'city': 'NORTH HIGHLANDS', 'zip': '95660', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '960', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '224252', 'latitude': '38.70355', 'longitude': '-121.375103'}
# This is row number 974
# ========================
# {'street': '2181 WINTERHAVEN CIR', 'city': 'CAMERON PARK', 'zip': '95682', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '0', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '224500', 'latitude': '38.69757', 'longitude': '-120.995739'}
# This is row number 975
# ========================
# {'street': '7540 HICKORY AVE', 'city': 'ORANGEVALE', 'zip': '95662', 'state': 'CA', 'beds': '3', 'baths': '1', 'sq__ft': '1456', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '225000', 'latitude': '38.703056', 'longitude': '-121.235221'}
# This is row number 976
# ========================
# {'street': '5024 CHAMBERLIN CIR', 'city': 'ELK GROVE', 'zip': '95757', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1450', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '228000', 'latitude': '38.389756', 'longitude': '-121.446246'}
# This is row number 977
# ========================
# {'street': '2400 INVERNESS DR', 'city': 'LINCOLN', 'zip': '95648', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1358', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '229027', 'latitude': '38.897814', 'longitude': '-121.324691'}
# This is row number 978
# ========================
# {'street': '5 BISHOPGATE CT', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1329', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '229500', 'latitude': '38.467936', 'longitude': '-121.445477'}
# This is row number 979
# ========================
# {'street': '5601 REXLEIGH DR', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1715', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '230000', 'latitude': '38.445342', 'longitude': '-121.441504'}
# This is row number 980
# ========================
# {'street': '1909 YARNELL WAY', 'city': 'ELK GROVE', 'zip': '95758', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1262', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '230000', 'latitude': '38.417382', 'longitude': '-121.484325'}
# This is row number 981
# ========================
# {'street': '9169 GARLINGTON CT', 'city': 'SACRAMENTO', 'zip': '95829', 'state': 'CA', 'beds': '4', 'baths': '3', 'sq__ft': '2280', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '232425', 'latitude': '38.457679', 'longitude': '-121.35962'}
# This is row number 982
# ========================
# {'street': '6932 RUSKUT WAY', 'city': 'SACRAMENTO', 'zip': '95823', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1477', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '234000', 'latitude': '38.499893', 'longitude': '-121.45889'}
# This is row number 983
# ========================
# {'street': '7933 DAFFODIL WAY', 'city': 'CITRUS HEIGHTS', 'zip': '95610', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1216', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '235000', 'latitude': '38.708824', 'longitude': '-121.256803'}
# This is row number 984
# ========================
# {'street': '8304 RED FOX WAY', 'city': 'ELK GROVE', 'zip': '95758', 'state': 'CA', 'beds': '4', 'baths': '2', 'sq__ft': '1685', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '235301', 'latitude': '38.417', 'longitude': '-121.397424'}
# This is row number 985
# ========================
# {'street': '3882 YELLOWSTONE LN', 'city': 'EL DORADO HILLS', 'zip': '95762', 'state': 'CA', 'beds': '3', 'baths': '2', 'sq__ft': '1362', 'type': 'Residential', 'sale_date': 'Thu May 15 00:00:00 EDT 2008', 'price': '235738', 'latitude': '38.655245', 'longitude': '-121.075915'}

# %% [markdown]
# ---
#
# **Tuple unpacking**

# %%
a = ["a", "b", "c"]
list(enumerate(a))
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c')]

# %%
l = ("Hello", "World")

# %%
h = l[0]
w = l[1]
print(h)
print(w)
# Out:
# Hello
# World

# %%
h, w = l
print(h)
print(w)
# Out:
# Hello
# World

# %%
h, w = ("Hello", "World")

# %% [markdown]
# ---

# %%
data = []
with open("data/sacramento_data.csv", "r") as csvfile:
    reader = csv.DictReader(csvfile)
    
    for i, row in enumerate(reader):
        data.append(row)

# %%
data[0]
# Out:
# {'street': '3526 HIGH ST',
#  'city': 'SACRAMENTO',
#  'zip': '95838',
#  'state': 'CA',
#  'beds': '2',
#  'baths': '1',
#  'sq__ft': '836',
#  'type': 'Residential',
#  'sale_date': 'Wed May 21 00:00:00 EDT 2008',
#  'price': '59222',
#  'latitude': '38.631913',
#  'longitude': '-121.434879'}

# %%
data[0]["beds"] + data[1]["beds"]
# Out:
# '23'

# %% [markdown]
# ### Tasks
#
# - Capitalize `city`
# - Convert `beds`, `baths`, `sq__ft`, `price` to `int`
# - Convert `latitude`, `longitude` to `float`
# - Convert `sq__ft` to `sq_m`
# - Turn `sale_date` into date format 'YYYY-MM-DD'
#
# After processing, export to clean csv file.
#
# We start the exercise with one row only

# %%
sample = data[23]

# %%
sample
# Out:
# {'street': '9 PASTURE CT',
#  'city': 'SACRAMENTO',
#  'zip': '95834',
#  'state': 'CA',
#  'beds': '3',
#  'baths': '2',
#  'sq__ft': '1601',
#  'type': 'Residential',
#  'sale_date': 'Wed May 21 00:00:00 EDT 2008',
#  'price': '124100',
#  'latitude': '38.628631',
#  'longitude': '-121.488097'}

# %% [markdown]
# ## 1. Capitalize `city`

# %%
sample["city"].capitalize()
# Out:
# 'Sacramento'

# %% [markdown]
# ## 2. Convert `beds` to `int`

# %%
int(sample["beds"])
# Out:
# 3

# %%
def to_int(row, column):
    return int(row[column])

# %%
to_int(sample, "beds")
# Out:
# 3

# %%
to_int(sample, "price")
# Out:
# 124100

# %% [markdown]
# Same approach for all other columns we want to turn into `int`
#
# ## 3. Convert `latitude` to `float`

# %%
float(sample["latitude"])
# Out:
# 38.628631

# %%
def to_float(row, column):
    return float(row[column])

# %%
to_float(sample, "latitude")
# Out:
# 38.628631

# %% [markdown]
# ## 4. Convert the value for `sq__ft` to a value with unit sqm

# %%
round(int(sample["sq__ft"]) / 10.764, 1)
# Out:
# 148.7

# %%
def to_sqm(row, column):
    return round(int(row[column]) / 10.764, 1)

# %%
to_sqm(sample, "sq__ft")
# Out:
# 148.7

# %% [markdown]
# # 5. Turn `sale_date` into 'YYYY-MM-DD'

# %%
sample["sale_date"]
# Out:
# 'Wed May 21 00:00:00 EDT 2008'

# %%
import re

# %% [markdown]
# ###  5.1. Extract year

# %%
sample["sale_date"]
# Out:
# 'Wed May 21 00:00:00 EDT 2008'

# %%
year_pattern = r"\d{4}$"
year, = re.findall(year_pattern, sample["sale_date"])

# %%
year
# Out:
# '2008'

# %%
def extract_year(row, column):
    year_pattern = r"\d{4}$"
    year, = re.findall(year_pattern, row[column])
    return year

# %%
extract_year(sample, "sale_date")
# Out:
# '2008'

# %% [markdown]
# ### 5.2. Extract day

# %%
day_pattern = r"\s(\d{2})\s"
day, = re.findall(day_pattern, sample["sale_date"])

# %%
day
# Out:
# '21'

# %%
def extract_day(row, column):
    day_pattern = r"\s(\d{2})\s"
    day, = re.findall(day_pattern, row[column])
    return day

# %%
extract_day(sample, "sale_date")
# Out:
# '21'

# %% [markdown]
# ---

# %%
a, b = [1,2]
print(a)
print(b)
# Out:
# 1
# 2

# %%
c, = [10]
print(c)
# Out:
# 10

# %% [markdown]
# ----

# %% [markdown]
# ### 5.3. Extract month

# %%
sample["sale_date"]
# Out:
# 'Wed May 21 00:00:00 EDT 2008'

# %%
month_pattern = r"^[A-Z][a-z]{2}\s([A-Z][a-z]+)\s"
month_str, = re.findall(month_pattern, sample["sale_date"])

# %%
test_month = 'Sun September 21 00:00:00 EDT 2008'
re.findall(month_pattern, test_month)
# Out:
# ['September']

# %%
month_str
# Out:
# 'May'

# %%
month_to_digit = {"January": "01",
                  "February": "02",
                  "March": "03",
                  "April": "04",
                  "May": "05",
                  "June": "06",
                  "July": "07",
                  "August": "08",
                  "September": "09",
                  "October": "10",
                  "November": "11",
                  "December": "12"}

# %%
month = month_to_digit[month_str]

# %%
def extract_month(row, column):
    month_to_digit = {"January": "01",
                  "February": "02",
                  "March": "03",
                  "April": "04",
                  "May": "05",
                  "June": "06",
                  "July": "07",
                  "August": "08",
                  "September": "09",
                  "October": "10",
                  "November": "11",
                  "December": "12"}
    month_pattern = r"^[A-Z][a-z]{2}\s([A-Z][a-z]+)\s"
    
    month_str, = re.findall(month_pattern, row[column])
    month = month_to_digit[month_str]
    return month

# %%
extract_month(sample, "sale_date")
# Out:
# '05'

# %% [markdown]
# ### 5.4. Combine date parts

# %%
year + "-" + month + "-" + day
# Out:
# '2008-05-21'

# %%
"-".join([year, month, day])
# Out:
# '2008-05-21'

# %%
def extract_date(row, column):
    return "-".join([extract_year(row, column),
                     extract_month(row, column),
                     extract_day(row, column)])

# %%
extract_date(sample, "sale_date")
# Out:
# '2008-05-21'

# %% [markdown]
# ## Wrap all individual functions into one object

# %%
conversions = {"zip": int,
               "beds": int,
               "baths": int}

# %%
sample
# Out:
# {'street': '9 PASTURE CT',
#  'city': 'SACRAMENTO',
#  'zip': '95834',
#  'state': 'CA',
#  'beds': '3',
#  'baths': '2',
#  'sq__ft': '1601',
#  'type': 'Residential',
#  'sale_date': 'Wed May 21 00:00:00 EDT 2008',
#  'price': '124100',
#  'latitude': '38.628631',
#  'longitude': '-121.488097'}

# %% [markdown]
# ---

# %%
s = {"a": 1, "b": 2}
for i in s:
    print(i)
    print(s[i])
# Out:
# a
# 1
# b
# 2

# %%
s = {"a": 1, "b": 2}
for key, value in s.items():
    print(key)
    print(value)
# Out:
# a
# 1
# b
# 2

# %%
list(s.items())
# Out:
# [('a', 1), ('b', 2)]

# %% [markdown]
# ---

# %%
sample
# Out:
# {'street': '9 PASTURE CT',
#  'city': 'SACRAMENTO',
#  'zip': '95834',
#  'state': 'CA',
#  'beds': '3',
#  'baths': '2',
#  'sq__ft': '1601',
#  'type': 'Residential',
#  'sale_date': 'Wed May 21 00:00:00 EDT 2008',
#  'price': '124100',
#  'latitude': '38.628631',
#  'longitude': '-121.488097'}

# %% [markdown]
# Refactor functions to take values instead of dict and column

# %%
def to_sqm(value):
    return round(int(value) / 10.764, 1)

def extract_year(value):
    year_pattern = r"\d{4}$"
    year, = re.findall(year_pattern, value)
    return year

def extract_month(value):
    month_to_digit = {"January": "01",
                  "February": "02",
                  "March": "03",
                  "April": "04",
                  "May": "05",
                  "June": "06",
                  "July": "07",
                  "August": "08",
                  "September": "09",
                  "October": "10",
                  "November": "11",
                  "December": "12"}
    month_pattern = r"^[A-Z][a-z]{2}\s([A-Z][a-z]+)\s"
    
    month_str, = re.findall(month_pattern, value)
    month = month_to_digit[month_str]
    return month

def extract_day(value):
    day_pattern = r"\s(\d{2})\s"
    day, = re.findall(day_pattern, value)
    return day

def extract_date(value):
    return "-".join([extract_year(value),
                     extract_month(value),
                     extract_day(value)])

def to_capitalize(value):
    return value.capitalize()

# %%
"SACRAMENTO".capitalize()
# Out:
# 'Sacramento'

# %%
to_capitalize("Sacramento")
# Out:
# 'Sacramento'

# %%
conversions = {"beds": int,
               "baths": int,
               "price": int,
               "sq__ft": to_sqm,
               "sale_date": extract_date,
               "latitude": float,
               "longitude": float,
               "city": lambda x: x.capitalize()}

# %%
sample
# Out:
# {'street': '9 PASTURE CT',
#  'city': 'SACRAMENTO',
#  'zip': '95834',
#  'state': 'CA',
#  'beds': '3',
#  'baths': '2',
#  'sq__ft': '1601',
#  'type': 'Residential',
#  'sale_date': 'Wed May 21 00:00:00 EDT 2008',
#  'price': '124100',
#  'latitude': '38.628631',
#  'longitude': '-121.488097'}

# %%
new_sample = {}
for column, value in sample.items():
    if column in conversions:
        new_sample[column] = conversions[column](value)
    else:
        new_sample[column] = value

# %%
new_sample
# Out:
# {'street': '9 PASTURE CT',
#  'city': 'Sacramento',
#  'zip': '95834',
#  'state': 'CA',
#  'beds': 3,
#  'baths': 2,
#  'sq__ft': 148.7,
#  'type': 'Residential',
#  'sale_date': '2008-05-21',
#  'price': 124100,
#  'latitude': 38.628631,
#  'longitude': -121.488097}

# %%
def process_row(row):
    conversions = {"beds": int,
               "baths": int,
               "price": int,
               "sq__ft": to_sqm,
               "sale_date": extract_date,
               "latitude": float,
               "longitude": float,
               "city": lambda x: x.title()}
    
    new_row = {}
    for column, value in row.items():
        if column in conversions:
            new_row["sq_m" if column == "sq__ft" else column] = conversions[column](value)
        else:
            new_row[column] = value
            
    return new_row

# %%
column = "sq__ft"
"sq_m" if column == "sq__ft" else column # ternary operator
# Out:
# 'sq_m'

# %%
process_row(data[101])
# Out:
# {'street': '4236 NATOMAS CENTRAL DR',
#  'city': 'Sacramento',
#  'zip': '95834',
#  'state': 'CA',
#  'beds': 3,
#  'baths': 2,
#  'sq_m': 155.3,
#  'type': 'Condo',
#  'sale_date': '2008-05-21',
#  'price': 265000,
#  'latitude': 38.648879,
#  'longitude': -121.544023}

# %%
type(data)
# Out:
# list

# %%
[process_row(row) for row in data]
# Out:
# [{'street': '3526 HIGH ST',
#   'city': 'Sacramento',
#   'zip': '95838',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 77.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 59222,
#   'latitude': 38.631913,
#   'longitude': -121.434879},
#  {'street': '51 OMAHA CT',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 108.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 68212,
#   'latitude': 38.478902,
#   'longitude': -121.431028},
#  {'street': '2796 BRANCH ST',
#   'city': 'Sacramento',
#   'zip': '95815',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 74.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 68880,
#   'latitude': 38.618305,
#   'longitude': -121.443839},
#  {'street': '2805 JANETTE WAY',
#   'city': 'Sacramento',
#   'zip': '95815',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 79.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 69307,
#   'latitude': 38.616835,
#   'longitude': -121.439146},
#  {'street': '6001 MCMAHON DR',
#   'city': 'Sacramento',
#   'zip': '95824',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 74.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 81900,
#   'latitude': 38.51947,
#   'longitude': -121.435768},
#  {'street': '5828 PEPPERMILL CT',
#   'city': 'Sacramento',
#   'zip': '95841',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 104.2,
#   'type': 'Condo',
#   'sale_date': '2008-05-21',
#   'price': 89921,
#   'latitude': 38.662595,
#   'longitude': -121.327813},
#  {'street': '6048 OGDEN NASH WAY',
#   'city': 'Sacramento',
#   'zip': '95842',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 102.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 90895,
#   'latitude': 38.681659,
#   'longitude': -121.351705},
#  {'street': '2561 19TH AVE',
#   'city': 'Sacramento',
#   'zip': '95820',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 109.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 91002,
#   'latitude': 38.535092,
#   'longitude': -121.481367},
#  {'street': '11150 TRINITY RIVER DR Unit 114',
#   'city': 'Rancho Cordova',
#   'zip': '95670',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 87.4,
#   'type': 'Condo',
#   'sale_date': '2008-05-21',
#   'price': 94905,
#   'latitude': 38.621188,
#   'longitude': -121.270555},
#  {'street': '7325 10TH ST',
#   'city': 'Rio Linda',
#   'zip': '95673',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 106.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 98937,
#   'latitude': 38.700909,
#   'longitude': -121.442979},
#  {'street': '645 MORRISON AVE',
#   'city': 'Sacramento',
#   'zip': '95838',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 84.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 100309,
#   'latitude': 38.637663,
#   'longitude': -121.45152},
#  {'street': '4085 FAWN CIR',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 119.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 106250,
#   'latitude': 38.470746,
#   'longitude': -121.458918},
#  {'street': '2930 LA ROSA RD',
#   'city': 'Sacramento',
#   'zip': '95815',
#   'state': 'CA',
#   'beds': 1,
#   'baths': 1,
#   'sq_m': 80.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 106852,
#   'latitude': 38.618698,
#   'longitude': -121.435833},
#  {'street': '2113 KIRK WAY',
#   'city': 'Sacramento',
#   'zip': '95822',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 94.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 107502,
#   'latitude': 38.482215,
#   'longitude': -121.492603},
#  {'street': '4533 LOCH HAVEN WAY',
#   'city': 'Sacramento',
#   'zip': '95842',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 94.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 108750,
#   'latitude': 38.672914,
#   'longitude': -121.35934},
#  {'street': '7340 HAMDEN PL',
#   'city': 'Sacramento',
#   'zip': '95842',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 105.4,
#   'type': 'Condo',
#   'sale_date': '2008-05-21',
#   'price': 110700,
#   'latitude': 38.700051,
#   'longitude': -121.351278},
#  {'street': '6715 6TH ST',
#   'city': 'Rio Linda',
#   'zip': '95673',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 78.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 113263,
#   'latitude': 38.689591,
#   'longitude': -121.452239},
#  {'street': '6236 LONGFORD DR Unit 1',
#   'city': 'Citrus Heights',
#   'zip': '95621',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 73.9,
#   'type': 'Condo',
#   'sale_date': '2008-05-21',
#   'price': 116250,
#   'latitude': 38.679776,
#   'longitude': -121.314089},
#  {'street': '250 PERALTA AVE',
#   'city': 'Sacramento',
#   'zip': '95833',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 54.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 120000,
#   'latitude': 38.612099,
#   'longitude': -121.469095},
#  {'street': '113 LEEWILL AVE',
#   'city': 'Rio Linda',
#   'zip': '95673',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 126.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 121630,
#   'latitude': 38.689999,
#   'longitude': -121.46322},
#  {'street': '6118 STONEHAND AVE',
#   'city': 'Citrus Heights',
#   'zip': '95621',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 103.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 122000,
#   'latitude': 38.707851,
#   'longitude': -121.320707},
#  {'street': '4882 BANDALIN WAY',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 123.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 122682,
#   'latitude': 38.468173,
#   'longitude': -121.444071},
#  {'street': '7511 OAKVALE CT',
#   'city': 'North Highlands',
#   'zip': '95660',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 115.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 123000,
#   'latitude': 38.702792,
#   'longitude': -121.38221},
#  {'street': '9 PASTURE CT',
#   'city': 'Sacramento',
#   'zip': '95834',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 148.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 124100,
#   'latitude': 38.628631,
#   'longitude': -121.488097},
#  {'street': '3729 BAINBRIDGE DR',
#   'city': 'North Highlands',
#   'zip': '95660',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 83.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 125000,
#   'latitude': 38.701499,
#   'longitude': -121.37622},
#  {'street': '3828 BLACKFOOT WAY',
#   'city': 'Antelope',
#   'zip': '95843',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 101.1,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 126640,
#   'latitude': 38.70974,
#   'longitude': -121.37377},
#  {'street': '4108 NORTON WAY',
#   'city': 'Sacramento',
#   'zip': '95820',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 89.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 127281,
#   'latitude': 38.537526,
#   'longitude': -121.478315},
#  {'street': '1469 JANRICK AVE',
#   'city': 'Sacramento',
#   'zip': '95832',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 104.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 129000,
#   'latitude': 38.476472,
#   'longitude': -121.501711},
#  {'street': '9861 CULP WAY',
#   'city': 'Sacramento',
#   'zip': '95827',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 128.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 131200,
#   'latitude': 38.558423,
#   'longitude': -121.327948},
#  {'street': '7825 CREEK VALLEY CIR',
#   'city': 'Sacramento',
#   'zip': '95828',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 115.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 132000,
#   'latitude': 38.472122,
#   'longitude': -121.404199},
#  {'street': '5201 LAGUNA OAKS DR Unit 140',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 96.5,
#   'type': 'Condo',
#   'sale_date': '2008-05-21',
#   'price': 133000,
#   'latitude': 38.423251,
#   'longitude': -121.444489},
#  {'street': '6768 MEDORA DR',
#   'city': 'North Highlands',
#   'zip': '95660',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 107.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 134555,
#   'latitude': 38.691161,
#   'longitude': -121.37192},
#  {'street': '3100 EXPLORER DR',
#   'city': 'Sacramento',
#   'zip': '95827',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 128.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 136500,
#   'latitude': 38.566663,
#   'longitude': -121.332644},
#  {'street': '7944 DOMINION WAY',
#   'city': 'Elverta',
#   'zip': '95626',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 103.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 138750,
#   'latitude': 38.713182,
#   'longitude': -121.411227},
#  {'street': '5201 LAGUNA OAKS DR Unit 162',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 96.5,
#   'type': 'Condo',
#   'sale_date': '2008-05-21',
#   'price': 141000,
#   'latitude': 38.423251,
#   'longitude': -121.444489},
#  {'street': '3920 SHINING STAR DR',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 131.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 146250,
#   'latitude': 38.48742,
#   'longitude': -121.462459},
#  {'street': '5031 CORVAIR ST',
#   'city': 'North Highlands',
#   'zip': '95660',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 100.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 147308,
#   'latitude': 38.658246,
#   'longitude': -121.375469},
#  {'street': '7661 NIXOS WAY',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 136.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 148750,
#   'latitude': 38.479553,
#   'longitude': -121.463317},
#  {'street': '7044 CARTHY WAY',
#   'city': 'Sacramento',
#   'zip': '95828',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 106.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 149593,
#   'latitude': 38.49857,
#   'longitude': -121.420925},
#  {'street': '2442 LARKSPUR LN',
#   'city': 'Sacramento',
#   'zip': '95825',
#   'state': 'CA',
#   'beds': 1,
#   'baths': 1,
#   'sq_m': 70.6,
#   'type': 'Condo',
#   'sale_date': '2008-05-21',
#   'price': 150000,
#   'latitude': 38.58514,
#   'longitude': -121.403736},
#  {'street': '4800 WESTLAKE PKWY Unit 2109',
#   'city': 'Sacramento',
#   'zip': '95835',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 121.1,
#   'type': 'Condo',
#   'sale_date': '2008-05-21',
#   'price': 152000,
#   'latitude': 38.658812,
#   'longitude': -121.542345},
#  {'street': '2178 63RD AVE',
#   'city': 'Sacramento',
#   'zip': '95822',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 112.1,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 154000,
#   'latitude': 38.493955,
#   'longitude': -121.48966},
#  {'street': '8718 ELK WAY',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 98.1,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 156896,
#   'latitude': 38.41653,
#   'longitude': -121.379653},
#  {'street': '5708 RIDGEPOINT DR',
#   'city': 'Antelope',
#   'zip': '95843',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 96.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 161250,
#   'latitude': 38.72027,
#   'longitude': -121.331555},
#  {'street': '7315 KOALA CT',
#   'city': 'North Highlands',
#   'zip': '95660',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 147.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 161500,
#   'latitude': 38.699251,
#   'longitude': -121.371414},
#  {'street': '2622 ERIN DR',
#   'city': 'Sacramento',
#   'zip': '95833',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 1,
#   'sq_m': 104.1,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 164000,
#   'latitude': 38.613765,
#   'longitude': -121.488694},
#  {'street': '8421 SUNBLAZE WAY',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 146.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 165000,
#   'latitude': 38.450543,
#   'longitude': -121.432538},
#  {'street': '7420 ALIX PKWY',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 1,
#   'sq_m': 181.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 166357,
#   'latitude': 38.489405,
#   'longitude': -121.452811},
#  {'street': '3820 NATOMA WAY',
#   'city': 'Sacramento',
#   'zip': '95838',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 153.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 166357,
#   'latitude': 38.636748,
#   'longitude': -121.422159},
#  {'street': '4431 GREEN TREE DR',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 137.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 168000,
#   'latitude': 38.499954,
#   'longitude': -121.454469},
#  {'street': '9417 SARA ST',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 110.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 170000,
#   'latitude': 38.415518,
#   'longitude': -121.370527},
#  {'street': '8299 HALBRITE WAY',
#   'city': 'Sacramento',
#   'zip': '95828',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 147.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 173000,
#   'latitude': 38.473814,
#   'longitude': -121.4},
#  {'street': '7223 KALLIE KAY LN',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 135.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 174250,
#   'latitude': 38.477553,
#   'longitude': -121.419463},
#  {'street': '8156 STEINBECK WAY',
#   'city': 'Sacramento',
#   'zip': '95828',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 159.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 174313,
#   'latitude': 38.474853,
#   'longitude': -121.406326},
#  {'street': '7957 VALLEY GREEN DR',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 110.1,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 178480,
#   'latitude': 38.465184,
#   'longitude': -121.434925},
#  {'street': '1122 WILD POPPY CT',
#   'city': 'Galt',
#   'zip': '95632',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 130.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 178760,
#   'latitude': 38.287789,
#   'longitude': -121.294715},
#  {'street': '4520 BOMARK WAY',
#   'city': 'Sacramento',
#   'zip': '95842',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 180.5,
#   'type': 'Multi-Family',
#   'sale_date': '2008-05-21',
#   'price': 179580,
#   'latitude': 38.665724,
#   'longitude': -121.358576},
#  {'street': '9012 KIEFER BLVD',
#   'city': 'Sacramento',
#   'zip': '95826',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 108.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 181000,
#   'latitude': 38.547011,
#   'longitude': -121.366217},
#  {'street': '5332 SANDSTONE ST',
#   'city': 'Carmichael',
#   'zip': '95608',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 107.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 181872,
#   'latitude': 38.662105,
#   'longitude': -121.313945},
#  {'street': '5993 SAWYER CIR',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 172.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 182587,
#   'latitude': 38.4473,
#   'longitude': -121.435218},
#  {'street': '4844 CLYDEBANK WAY',
#   'city': 'Antelope',
#   'zip': '95843',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 112.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 182716,
#   'latitude': 38.714609,
#   'longitude': -121.347887},
#  {'street': '306 CAMELLIA WAY',
#   'city': 'Galt',
#   'zip': '95632',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 105.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 182750,
#   'latitude': 38.260443,
#   'longitude': -121.297864},
#  {'street': '9021 MADISON AVE',
#   'city': 'Orangevale',
#   'zip': '95662',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 148.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 183200,
#   'latitude': 38.664186,
#   'longitude': -121.217511},
#  {'street': '404 6TH ST',
#   'city': 'Galt',
#   'zip': '95632',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 137.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 188741,
#   'latitude': 38.251808,
#   'longitude': -121.302493},
#  {'street': '8317 SUNNY CREEK WAY',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 131.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 189000,
#   'latitude': 38.459041,
#   'longitude': -121.424644},
#  {'street': '2617 BASS CT',
#   'city': 'Sacramento',
#   'zip': '95826',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 118.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 192067,
#   'latitude': 38.560767,
#   'longitude': -121.377471},
#  {'street': '7005 TIANT WAY',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 147.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 194000,
#   'latitude': 38.422811,
#   'longitude': -121.423285},
#  {'street': '7895 CABER WAY',
#   'city': 'Antelope',
#   'zip': '95843',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 126.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 194818,
#   'latitude': 38.711279,
#   'longitude': -121.393449},
#  {'street': '7624 BOGEY CT',
#   'city': 'Sacramento',
#   'zip': '95828',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 4,
#   'sq_m': 200.9,
#   'type': 'Multi-Family',
#   'sale_date': '2008-05-21',
#   'price': 195000,
#   'latitude': 38.48009,
#   'longitude': -121.415102},
#  {'street': '6930 HAMPTON COVE WAY',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 117.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 198000,
#   'latitude': 38.44004,
#   'longitude': -121.421012},
#  {'street': '8708 MESA BROOK WAY',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 159.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 199500,
#   'latitude': 38.44076,
#   'longitude': -121.385792},
#  {'street': '120 GRANT LN',
#   'city': 'Folsom',
#   'zip': '95630',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 169.1,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 200000,
#   'latitude': 38.687742,
#   'longitude': -121.17104},
#  {'street': '5907 ELLERSLEE DR',
#   'city': 'Carmichael',
#   'zip': '95608',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 87.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 200000,
#   'latitude': 38.664468,
#   'longitude': -121.32683},
#  {'street': '17 SERASPI CT',
#   'city': 'Sacramento',
#   'zip': '95834',
#   'state': 'CA',
#   'beds': 0,
#   'baths': 0,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 206000,
#   'latitude': 38.631481,
#   'longitude': -121.50188},
#  {'street': '170 PENHOW CIR',
#   'city': 'Sacramento',
#   'zip': '95834',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 140.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 208000,
#   'latitude': 38.653439,
#   'longitude': -121.535169},
#  {'street': '8345 STAR THISTLE WAY',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 147.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 212864,
#   'latitude': 38.454349,
#   'longitude': -121.439239},
#  {'street': '9080 FRESCA WAY',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 148.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 221000,
#   'latitude': 38.427818,
#   'longitude': -121.424026},
#  {'street': '391 NATALINO CIR',
#   'city': 'Sacramento',
#   'zip': '95835',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 124.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 221000,
#   'latitude': 38.67307,
#   'longitude': -121.506373},
#  {'street': '8373 BLACKMAN WAY',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 5,
#   'baths': 3,
#   'sq_m': 198.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 223058,
#   'latitude': 38.435436,
#   'longitude': -121.394536},
#  {'street': '9837 CORTE DORADO CT',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 150.1,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 227887,
#   'latitude': 38.400676,
#   'longitude': -121.38101},
#  {'street': '5037 J PKWY',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 137.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 231477,
#   'latitude': 38.491399,
#   'longitude': -121.443547},
#  {'street': '10245 LOS PALOS DR',
#   'city': 'Rancho Cordova',
#   'zip': '95670',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 119.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 234697,
#   'latitude': 38.593699,
#   'longitude': -121.31089},
#  {'street': '6613 NAVION DR',
#   'city': 'Citrus Heights',
#   'zip': '95621',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 118.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 235000,
#   'latitude': 38.702855,
#   'longitude': -121.31308},
#  {'street': '2887 AZEVEDO DR',
#   'city': 'Sacramento',
#   'zip': '95833',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 134.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 236000,
#   'latitude': 38.618457,
#   'longitude': -121.509439},
#  {'street': '9186 KINBRACE CT',
#   'city': 'Sacramento',
#   'zip': '95829',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 207.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 236685,
#   'latitude': 38.463355,
#   'longitude': -121.358936},
#  {'street': '4243 MIDDLEBURY WAY',
#   'city': 'Mather',
#   'zip': '95655',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 194.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 237800,
#   'latitude': 38.547991,
#   'longitude': -121.280483},
#  {'street': '1028 FALLON PLACE CT',
#   'city': 'Rio Linda',
#   'zip': '95673',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 110.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 240122,
#   'latitude': 38.693818,
#   'longitude': -121.441153},
#  {'street': '4804 NORIKER DR',
#   'city': 'Elk Grove',
#   'zip': '95757',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 200.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 242638,
#   'latitude': 38.400974,
#   'longitude': -121.448424},
#  {'street': '7713 HARVEST WOODS DR',
#   'city': 'Sacramento',
#   'zip': '95828',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 117.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 244000,
#   'latitude': 38.478198,
#   'longitude': -121.412911},
#  {'street': '2866 KARITSA AVE',
#   'city': 'Sacramento',
#   'zip': '95833',
#   'state': 'CA',
#   'beds': 0,
#   'baths': 0,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 244500,
#   'latitude': 38.626671,
#   'longitude': -121.52597},
#  {'street': '6913 RICHEVE WAY',
#   'city': 'Sacramento',
#   'zip': '95828',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 89.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 244960,
#   'latitude': 38.502519,
#   'longitude': -121.420769},
#  {'street': '8636 TEGEA WAY',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 5,
#   'baths': 3,
#   'sq_m': 233.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 245918,
#   'latitude': 38.443832,
#   'longitude': -121.382087},
#  {'street': '5448 MAIDSTONE WAY',
#   'city': 'Citrus Heights',
#   'zip': '95621',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 121.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 250000,
#   'latitude': 38.665395,
#   'longitude': -121.293288},
#  {'street': '18 OLLIE CT',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 147.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 250000,
#   'latitude': 38.444909,
#   'longitude': -121.412345},
#  {'street': '4010 ALEX LN',
#   'city': 'Carmichael',
#   'zip': '95608',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 123.2,
#   'type': 'Condo',
#   'sale_date': '2008-05-21',
#   'price': 250134,
#   'latitude': 38.637028,
#   'longitude': -121.312963},
#  {'street': '4901 MILLNER WAY',
#   'city': 'Elk Grove',
#   'zip': '95757',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 171.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 254200,
#   'latitude': 38.38692,
#   'longitude': -121.447349},
#  {'street': '4818 BRITTNEY LEE CT',
#   'city': 'Sacramento',
#   'zip': '95841',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 178.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 254200,
#   'latitude': 38.653917,
#   'longitude': -121.34218},
#  {'street': '5529 LAGUNA PARK DR',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 5,
#   'baths': 3,
#   'sq_m': 259.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 258000,
#   'latitude': 38.42568,
#   'longitude': -121.438062},
#  {'street': '230 CANDELA CIR',
#   'city': 'Sacramento',
#   'zip': '95835',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 143.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 260000,
#   'latitude': 38.656251,
#   'longitude': -121.547572},
#  {'street': '4900 71ST ST',
#   'city': 'Sacramento',
#   'zip': '95820',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 94.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 260014,
#   'latitude': 38.53151,
#   'longitude': -121.421089},
#  {'street': '12209 CONSERVANCY WAY',
#   'city': 'Rancho Cordova',
#   'zip': '95742',
#   'state': 'CA',
#   'beds': 0,
#   'baths': 0,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 263500,
#   'latitude': 38.553867,
#   'longitude': -121.219141},
#  {'street': '4236 NATOMAS CENTRAL DR',
#   'city': 'Sacramento',
#   'zip': '95834',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 155.3,
#   'type': 'Condo',
#   'sale_date': '2008-05-21',
#   'price': 265000,
#   'latitude': 38.648879,
#   'longitude': -121.544023},
#  {'street': '5615 LUPIN LN',
#   'city': 'Pollock Pines',
#   'zip': '95726',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 128.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 265000,
#   'latitude': 38.708315,
#   'longitude': -120.603872},
#  {'street': '5625 JAMES WAY',
#   'city': 'Sacramento',
#   'zip': '95822',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 90.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 271742,
#   'latitude': 38.523947,
#   'longitude': -121.484946},
#  {'street': '7842 LAHONTAN CT',
#   'city': 'Sacramento',
#   'zip': '95829',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 220.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 273750,
#   'latitude': 38.472976,
#   'longitude': -121.318633},
#  {'street': '6850 21ST ST',
#   'city': 'Sacramento',
#   'zip': '95822',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 134.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 275086,
#   'latitude': 38.502194,
#   'longitude': -121.490795},
#  {'street': '2900 BLAIR RD',
#   'city': 'Pollock Pines',
#   'zip': '95726',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 119.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 280908,
#   'latitude': 38.75485,
#   'longitude': -120.60476},
#  {'street': '2064 EXPEDITION WAY',
#   'city': 'Sacramento',
#   'zip': '95832',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 279.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 280987,
#   'latitude': 38.474099,
#   'longitude': -121.490711},
#  {'street': '2912 NORCADE CIR',
#   'city': 'Sacramento',
#   'zip': '95826',
#   'state': 'CA',
#   'beds': 8,
#   'baths': 4,
#   'sq_m': 335.6,
#   'type': 'Multi-Family',
#   'sale_date': '2008-05-21',
#   'price': 282400,
#   'latitude': 38.559505,
#   'longitude': -121.364839},
#  {'street': '9507 SEA CLIFF WAY',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 191.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 285000,
#   'latitude': 38.410992,
#   'longitude': -121.479043},
#  {'street': '8882 AUTUMN GOLD CT',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 185.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 287417,
#   'latitude': 38.4439,
#   'longitude': -121.37255},
#  {'street': '5322 WHITE LOTUS WAY',
#   'city': 'Elk Grove',
#   'zip': '95757',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 172.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 291000,
#   'latitude': 38.391538,
#   'longitude': -121.442596},
#  {'street': '1838 CASTRO WAY',
#   'city': 'Sacramento',
#   'zip': '95818',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 104.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 292024,
#   'latitude': 38.556098,
#   'longitude': -121.490787},
#  {'street': '10158 CRAWFORD WAY',
#   'city': 'Sacramento',
#   'zip': '95827',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 4,
#   'sq_m': 205.6,
#   'type': 'Multi-Family',
#   'sale_date': '2008-05-21',
#   'price': 297000,
#   'latitude': 38.5703,
#   'longitude': -121.315735},
#  {'street': '7731 MASTERS ST',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 5,
#   'baths': 3,
#   'sq_m': 231.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 297000,
#   'latitude': 38.442031,
#   'longitude': -121.410873},
#  {'street': '4925 PERCHERON DR',
#   'city': 'Elk Grove',
#   'zip': '95757',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 171.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 298000,
#   'latitude': 38.40154,
#   'longitude': -121.447649},
#  {'street': '2010 PROMONTORY POINT LN',
#   'city': 'Gold River',
#   'zip': '95670',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 141.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 299000,
#   'latitude': 38.62869,
#   'longitude': -121.261669},
#  {'street': '4727 SAVOIE WAY',
#   'city': 'Sacramento',
#   'zip': '95835',
#   'state': 'CA',
#   'beds': 5,
#   'baths': 3,
#   'sq_m': 260.1,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 304037,
#   'latitude': 38.658182,
#   'longitude': -121.549521},
#  {'street': '8664 MAGNOLIA HILL WAY',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 214.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 311000,
#   'latitude': 38.442352,
#   'longitude': -121.389675},
#  {'street': '9570 HARVEST ROSE WAY',
#   'city': 'Sacramento',
#   'zip': '95827',
#   'state': 'CA',
#   'beds': 5,
#   'baths': 3,
#   'sq_m': 219.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 315537,
#   'latitude': 38.555993,
#   'longitude': -121.340352},
#  {'street': '4359 CREGAN CT',
#   'city': 'Rancho Cordova',
#   'zip': '95742',
#   'state': 'CA',
#   'beds': 5,
#   'baths': 4,
#   'sq_m': 326.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 320000,
#   'latitude': 38.545128,
#   'longitude': -121.224922},
#  {'street': '5337 DUSTY ROSE WAY',
#   'city': 'Rancho Cordova',
#   'zip': '95742',
#   'state': 'CA',
#   'beds': 0,
#   'baths': 0,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 320000,
#   'latitude': 38.528575,
#   'longitude': -121.2286},
#  {'street': '8929 SUTTERS GOLD DR',
#   'city': 'Sacramento',
#   'zip': '95826',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 177.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 328360,
#   'latitude': 38.550848,
#   'longitude': -121.370224},
#  {'street': '8025 PEERLESS AVE',
#   'city': 'Orangevale',
#   'zip': '95662',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 157.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 334150,
#   'latitude': 38.71147,
#   'longitude': -121.216214},
#  {'street': '4620 WELERA WAY',
#   'city': 'Elk Grove',
#   'zip': '95757',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 3,
#   'sq_m': 253.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 335750,
#   'latitude': 38.398609,
#   'longitude': -121.450148},
#  {'street': '9723 TERRAPIN CT',
#   'city': 'Elk Grove',
#   'zip': '95757',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 218.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 335750,
#   'latitude': 38.403492,
#   'longitude': -121.430224},
#  {'street': '2115 SMOKESTACK WAY',
#   'city': 'Sacramento',
#   'zip': '95833',
#   'state': 'CA',
#   'beds': 0,
#   'baths': 0,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 339500,
#   'latitude': 38.602416,
#   'longitude': -121.542965},
#  {'street': '100 REBECCA WAY',
#   'city': 'Folsom',
#   'zip': '95630',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 203.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 344250,
#   'latitude': 38.68479,
#   'longitude': -121.149199},
#  {'street': '9488 OAK VILLAGE WAY',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 167.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 346210,
#   'latitude': 38.41333,
#   'longitude': -121.404999},
#  {'street': '8495 DARTFORD DR',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 3,
#   'sq_m': 182.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 347029,
#   'latitude': 38.448507,
#   'longitude': -121.421346},
#  {'street': '6708 PONTA DO SOL WAY',
#   'city': 'Elk Grove',
#   'zip': '95757',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 291.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 347650,
#   'latitude': 38.380635,
#   'longitude': -121.425538},
#  {'street': '4143 SEA MEADOW WAY',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 177.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 351300,
#   'latitude': 38.46534,
#   'longitude': -121.457519},
#  {'street': '3020 RICHARDSON CIR',
#   'city': 'El Dorado Hills',
#   'zip': '95762',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 352000,
#   'latitude': 38.691299,
#   'longitude': -121.081752},
#  {'street': '8082 LINDA ISLE LN',
#   'city': 'Sacramento',
#   'zip': '95831',
#   'state': 'CA',
#   'beds': 0,
#   'baths': 0,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 370000,
#   'latitude': 38.4772,
#   'longitude': -121.5215},
#  {'street': '15300 MURIETA SOUTH PKWY',
#   'city': 'Rancho Murieta',
#   'zip': '95683',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 254.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 370500,
#   'latitude': 38.4874,
#   'longitude': -121.075129},
#  {'street': '11215 SHARRMONT CT',
#   'city': 'Wilton',
#   'zip': '95693',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 196.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 372000,
#   'latitude': 38.35062,
#   'longitude': -121.228349},
#  {'street': '7105 DANBERG WAY',
#   'city': 'Elk Grove',
#   'zip': '95757',
#   'state': 'CA',
#   'beds': 5,
#   'baths': 3,
#   'sq_m': 293.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 375000,
#   'latitude': 38.4019,
#   'longitude': -121.420388},
#  {'street': '5579 JERRY LITELL WAY',
#   'city': 'Sacramento',
#   'zip': '95835',
#   'state': 'CA',
#   'beds': 5,
#   'baths': 3,
#   'sq_m': 334.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 381300,
#   'latitude': 38.677126,
#   'longitude': -121.500519},
#  {'street': '1050 FOXHALL WAY',
#   'city': 'Sacramento',
#   'zip': '95831',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 190.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 381942,
#   'latitude': 38.509819,
#   'longitude': -121.519661},
#  {'street': '7837 ABBINGTON WAY',
#   'city': 'Antelope',
#   'zip': '95843',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 170.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 387731,
#   'latitude': 38.709873,
#   'longitude': -121.339472},
#  {'street': '1300 F ST',
#   'city': 'Sacramento',
#   'zip': '95814',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 3,
#   'sq_m': 151.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 391000,
#   'latitude': 38.58355,
#   'longitude': -121.487289},
#  {'street': '6801 RAWLEY WAY',
#   'city': 'Elk Grove',
#   'zip': '95757',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 319.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 394470,
#   'latitude': 38.408351,
#   'longitude': -121.423925},
#  {'street': '1693 SHELTER COVE DR',
#   'city': 'Greenwood',
#   'zip': '95635',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 264.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 395000,
#   'latitude': 38.945357,
#   'longitude': -120.908822},
#  {'street': '9361 WADDELL LN',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 219.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 400186,
#   'latitude': 38.450829,
#   'longitude': -121.349928},
#  {'street': '10 SEA FOAM CT',
#   'city': 'Sacramento',
#   'zip': '95831',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 3,
#   'sq_m': 190.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 415000,
#   'latitude': 38.487885,
#   'longitude': -121.545947},
#  {'street': '6945 RIO TEJO WAY',
#   'city': 'Elk Grove',
#   'zip': '95757',
#   'state': 'CA',
#   'beds': 5,
#   'baths': 3,
#   'sq_m': 318.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 425000,
#   'latitude': 38.385638,
#   'longitude': -121.422616},
#  {'street': '4186 TULIP PARK WAY',
#   'city': 'Rancho Cordova',
#   'zip': '95742',
#   'state': 'CA',
#   'beds': 5,
#   'baths': 3,
#   'sq_m': 335.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 430000,
#   'latitude': 38.550617,
#   'longitude': -121.23526},
#  {'street': '9278 DAIRY CT',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 0,
#   'baths': 0,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 445000,
#   'latitude': 38.420338,
#   'longitude': -121.363757},
#  {'street': '207 ORANGE BLOSSOM CIR Unit C',
#   'city': 'Folsom',
#   'zip': '95630',
#   'state': 'CA',
#   'beds': 5,
#   'baths': 3,
#   'sq_m': 249.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 460000,
#   'latitude': 38.646273,
#   'longitude': -121.175322},
#  {'street': '6507 RIO DE ONAR WAY',
#   'city': 'Elk Grove',
#   'zip': '95757',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 253.1,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 461000,
#   'latitude': 38.38253,
#   'longitude': -121.428007},
#  {'street': '7004 RAWLEY WAY',
#   'city': 'Elk Grove',
#   'zip': '95757',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 319.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 489332,
#   'latitude': 38.406421,
#   'longitude': -121.422081},
#  {'street': '6503 RIO DE ONAR WAY',
#   'city': 'Elk Grove',
#   'zip': '95757',
#   'state': 'CA',
#   'beds': 5,
#   'baths': 4,
#   'sq_m': 325.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 510000,
#   'latitude': 38.38253,
#   'longitude': -121.428038},
#  {'street': '2217 APPALOOSA CT',
#   'city': 'Folsom',
#   'zip': '95630',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 228.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 539000,
#   'latitude': 38.655167,
#   'longitude': -121.090178},
#  {'street': '868 HILDEBRAND CIR',
#   'city': 'Folsom',
#   'zip': '95630',
#   'state': 'CA',
#   'beds': 0,
#   'baths': 0,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 585000,
#   'latitude': 38.670947,
#   'longitude': -121.097727},
#  {'street': '6030 PALERMO WAY',
#   'city': 'El Dorado Hills',
#   'zip': '95762',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 600000,
#   'latitude': 38.672761,
#   'longitude': -121.050378},
#  {'street': '4070 REDONDO DR',
#   'city': 'El Dorado Hills',
#   'zip': '95762',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 606238,
#   'latitude': 38.666807,
#   'longitude': -121.06483},
#  {'street': '4004 CRESTA WAY',
#   'city': 'Sacramento',
#   'zip': '95864',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 3,
#   'sq_m': 216.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 660000,
#   'latitude': 38.591618,
#   'longitude': -121.370626},
#  {'street': '315 JUMEL CT',
#   'city': 'El Dorado Hills',
#   'zip': '95762',
#   'state': 'CA',
#   'beds': 6,
#   'baths': 5,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-21',
#   'price': 830000,
#   'latitude': 38.669931,
#   'longitude': -121.05958},
#  {'street': '6272 LONGFORD DR Unit 1',
#   'city': 'Citrus Heights',
#   'zip': '95621',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 73.9,
#   'type': 'Condo',
#   'sale_date': '2008-05-20',
#   'price': 69000,
#   'latitude': 38.680923,
#   'longitude': -121.313945},
#  {'street': '3432 Y ST',
#   'city': 'Sacramento',
#   'zip': '95817',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 102.1,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 70000,
#   'latitude': 38.554967,
#   'longitude': -121.468046},
#  {'street': '9512 EMERALD PARK DR Unit 3',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 78.0,
#   'type': 'Condo',
#   'sale_date': '2008-05-20',
#   'price': 71000,
#   'latitude': 38.40573,
#   'longitude': -121.369832},
#  {'street': '3132 CLAY ST',
#   'city': 'Sacramento',
#   'zip': '95815',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 74.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 78000,
#   'latitude': 38.624678,
#   'longitude': -121.439203},
#  {'street': '5221 38TH AVE',
#   'city': 'Sacramento',
#   'zip': '95824',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 69.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 78400,
#   'latitude': 38.518044,
#   'longitude': -121.443555},
#  {'street': '6112 HERMOSA ST',
#   'city': 'Sacramento',
#   'zip': '95822',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 99.1,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 80000,
#   'latitude': 38.515125,
#   'longitude': -121.480416},
#  {'street': '483 ARCADE BLVD',
#   'city': 'Sacramento',
#   'zip': '95815',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 122.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 89000,
#   'latitude': 38.623571,
#   'longitude': -121.454884},
#  {'street': '671 SONOMA AVE',
#   'city': 'Sacramento',
#   'zip': '95815',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 124.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 90000,
#   'latitude': 38.622953,
#   'longitude': -121.450142},
#  {'street': '5980 79TH ST',
#   'city': 'Sacramento',
#   'zip': '95824',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 80.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 90000,
#   'latitude': 38.518373,
#   'longitude': -121.411779},
#  {'street': '7607 ELDER CREEK RD',
#   'city': 'Sacramento',
#   'zip': '95824',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 85.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 92000,
#   'latitude': 38.51055,
#   'longitude': -121.414768},
#  {'street': '5028 14TH AVE',
#   'city': 'Sacramento',
#   'zip': '95820',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 56.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 93675,
#   'latitude': 38.53942,
#   'longitude': -121.446894},
#  {'street': '14788 NATCHEZ CT',
#   'city': 'Rancho Murieta',
#   'zip': '95683',
#   'state': 'CA',
#   'beds': 0,
#   'baths': 0,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 97750,
#   'latitude': 38.492287,
#   'longitude': -121.100032},
#  {'street': '1069 ACACIA AVE',
#   'city': 'Sacramento',
#   'zip': '95815',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 113.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 98000,
#   'latitude': 38.621998,
#   'longitude': -121.442238},
#  {'street': '5201 LAGUNA OAKS DR Unit 199',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 1,
#   'baths': 1,
#   'sq_m': 67.1,
#   'type': 'Condo',
#   'sale_date': '2008-05-20',
#   'price': 98000,
#   'latitude': 38.423251,
#   'longitude': -121.444489},
#  {'street': '3847 LAS PASAS WAY',
#   'city': 'Sacramento',
#   'zip': '95864',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 152.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 99000,
#   'latitude': 38.588672,
#   'longitude': -121.373916},
#  {'street': '5201 LAGUNA OAKS DR Unit 172',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 1,
#   'baths': 1,
#   'sq_m': 67.1,
#   'type': 'Condo',
#   'sale_date': '2008-05-20',
#   'price': 100000,
#   'latitude': 38.423251,
#   'longitude': -121.444489},
#  {'street': '1121 CREEKSIDE WAY',
#   'city': 'Galt',
#   'zip': '95632',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 100.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 106716,
#   'latitude': 38.241514,
#   'longitude': -121.312199},
#  {'street': '5307 CABRILLO WAY',
#   'city': 'Sacramento',
#   'zip': '95820',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 96.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 111000,
#   'latitude': 38.52712,
#   'longitude': -121.435348},
#  {'street': '3725 DON JULIO BLVD',
#   'city': 'North Highlands',
#   'zip': '95660',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 97.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 111000,
#   'latitude': 38.67895,
#   'longitude': -121.379406},
#  {'street': '4803 MCCLOUD DR',
#   'city': 'Sacramento',
#   'zip': '95842',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 89.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 114800,
#   'latitude': 38.682279,
#   'longitude': -121.352817},
#  {'street': '10542 SILVERWOOD WAY',
#   'city': 'Rancho Cordova',
#   'zip': '95670',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 102.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 120108,
#   'latitude': 38.587156,
#   'longitude': -121.295778},
#  {'street': '6318 39TH AVE',
#   'city': 'Sacramento',
#   'zip': '95824',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 97.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 123225,
#   'latitude': 38.518942,
#   'longitude': -121.430158},
#  {'street': '211 MCDANIEL CIR',
#   'city': 'Sacramento',
#   'zip': '95838',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 103.1,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 123750,
#   'latitude': 38.636565,
#   'longitude': -121.460383},
#  {'street': '3800 LYNHURST WAY',
#   'city': 'North Highlands',
#   'zip': '95660',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 82.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 125000,
#   'latitude': 38.650445,
#   'longitude': -121.374861},
#  {'street': '6139 HERMOSA ST',
#   'city': 'Sacramento',
#   'zip': '95822',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 104.1,
#   'type': 'Residential',
#   'sale_date': '2008-05-20',
#   'price': 125000,
#   'latitude': 38.514665,
#   'longitude': -121.480411},
#  {'street': '2505 RHINE WAY',
#   'city': 'Elverta',
#   'zip': '95626',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 100.3,
# ...
#  {'street': '7740 DIXIE LOU ST',
#   'city': 'Sacramento',
#   'zip': '95832',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 114.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 170000,
#   'latitude': 38.475853,
#   'longitude': -121.477039},
#  {'street': '7342 DAVE ST',
#   'city': 'Sacramento',
#   'zip': '95828',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 152.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 170725,
#   'latitude': 38.490822,
#   'longitude': -121.401643},
#  {'street': '7687 HOWERTON DR',
#   'city': 'Sacramento',
#   'zip': '95831',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 109.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 171750,
#   'latitude': 38.480859,
#   'longitude': -121.539745},
#  {'street': '26 KAMSON CT',
#   'city': 'Sacramento',
#   'zip': '95833',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 147.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 172000,
#   'latitude': 38.622794,
#   'longitude': -121.499173},
#  {'street': '7045 PEEVEY CT',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 84.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 173056,
#   'latitude': 38.502254,
#   'longitude': -121.451444},
#  {'street': '8916 GABLES MILL PL',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 124.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 174000,
#   'latitude': 38.433919,
#   'longitude': -121.422347},
#  {'street': '1140 EDMONTON DR',
#   'city': 'Sacramento',
#   'zip': '95833',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 111.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 174250,
#   'latitude': 38.62457,
#   'longitude': -121.486913},
#  {'street': '8879 APPLE PEAR CT',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 137.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 176850,
#   'latitude': 38.44574,
#   'longitude': -121.3725},
#  {'street': '9 WIND CT',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 139.1,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 179500,
#   'latitude': 38.45073,
#   'longitude': -121.427528},
#  {'street': '8570 SHERATON DR',
#   'city': 'Fair Oaks',
#   'zip': '95628',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 89.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 185000,
#   'latitude': 38.667254,
#   'longitude': -121.240708},
#  {'street': '1550 TOPANGA LN Unit 207',
#   'city': 'Lincoln',
#   'zip': '95648',
#   'state': 'CA',
#   'beds': 0,
#   'baths': 0,
#   'sq_m': 0.0,
#   'type': 'Condo',
#   'sale_date': '2008-05-15',
#   'price': 188000,
#   'latitude': 38.88417,
#   'longitude': -121.270222},
#  {'street': '1080 RIO NORTE WAY',
#   'city': 'Sacramento',
#   'zip': '95834',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 132.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 188700,
#   'latitude': 38.634335,
#   'longitude': -121.486098},
#  {'street': '5501 VALLETTA WAY',
#   'city': 'Sacramento',
#   'zip': '95820',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 96.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 189000,
#   'latitude': 38.530144,
#   'longitude': -121.43749},
#  {'street': '5624 MEMORY LN',
#   'city': 'Fair Oaks',
#   'zip': '95628',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 142.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 189000,
#   'latitude': 38.66745,
#   'longitude': -121.2364},
#  {'street': '6622 WILLOWLEAF DR',
#   'city': 'Citrus Heights',
#   'zip': '95621',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 175.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 189836,
#   'latitude': 38.699714,
#   'longitude': -121.311635},
#  {'street': '27 MEGAN CT',
#   'city': 'Sacramento',
#   'zip': '95838',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 175.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 190000,
#   'latitude': 38.649258,
#   'longitude': -121.465308},
#  {'street': '6601 WOODMORE OAKS DR',
#   'city': 'Orangevale',
#   'zip': '95662',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 120.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 191250,
#   'latitude': 38.687006,
#   'longitude': -121.254319},
#  {'street': '1973 DANVERS WAY',
#   'city': 'Sacramento',
#   'zip': '95832',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 152.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 191675,
#   'latitude': 38.477568,
#   'longitude': -121.492574},
#  {'street': '8001 ARROYO VISTA DR',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 155.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 195500,
#   'latitude': 38.46734,
#   'longitude': -121.419843},
#  {'street': '7409 VOYAGER WAY',
#   'city': 'Citrus Heights',
#   'zip': '95621',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 99.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 198000,
#   'latitude': 38.700717,
#   'longitude': -121.3133},
#  {'street': '815 CROSSWIND DR',
#   'city': 'Sacramento',
#   'zip': '95838',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 114.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 200000,
#   'latitude': 38.651386,
#   'longitude': -121.45042},
#  {'street': '5509 LAGUNA CREST WAY',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 109.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 200000,
#   'latitude': 38.42442,
#   'longitude': -121.440357},
#  {'street': '8424 MERRY HILL WAY',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 131.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 200000,
#   'latitude': 38.452075,
#   'longitude': -121.366461},
#  {'street': '1525 PENNSYLVANIA AVE',
#   'city': 'West Sacramento',
#   'zip': '95691',
#   'state': 'CA',
#   'beds': 0,
#   'baths': 0,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 200100,
#   'latitude': 38.569943,
#   'longitude': -121.527539},
#  {'street': '5954 BRIDGECROSS DR',
#   'city': 'Sacramento',
#   'zip': '95835',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 126.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 201528,
#   'latitude': 38.68197,
#   'longitude': -121.500025},
#  {'street': '8789 SEQUOIA WOOD CT',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 149.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 204750,
#   'latitude': 38.438818,
#   'longitude': -121.37443},
#  {'street': '6600 SILVERTHORNE CIR',
#   'city': 'Sacramento',
#   'zip': '95842',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 182.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 205000,
#   'latitude': 38.68607,
#   'longitude': -121.342369},
#  {'street': '2221 2ND AVE',
#   'city': 'Sacramento',
#   'zip': '95818',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 101.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 205000,
#   'latitude': 38.555781,
#   'longitude': -121.485331},
#  {'street': '3230 SMATHERS WAY',
#   'city': 'Carmichael',
#   'zip': '95608',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 120.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 205900,
#   'latitude': 38.623372,
#   'longitude': -121.347665},
#  {'street': '5209 LAGUNA CREST WAY',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 2,
#   'sq_m': 110.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 207000,
#   'latitude': 38.424421,
#   'longitude': -121.443915},
#  {'street': '416 LEITCH AVE',
#   'city': 'Sacramento',
#   'zip': '95815',
#   'state': 'CA',
#   'beds': 2,
#   'baths': 1,
#   'sq_m': 73.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 207973,
#   'latitude': 38.612694,
#   'longitude': -121.456669},
#  {'street': '2100 BEATTY WAY',
#   'city': 'Roseville',
#   'zip': '95747',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 127.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 208250,
#   'latitude': 38.737882,
#   'longitude': -121.308142},
#  {'street': '6920 GILLINGHAM WAY',
#   'city': 'North Highlands',
#   'zip': '95660',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 121.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 208318,
#   'latitude': 38.694279,
#   'longitude': -121.373395},
#  {'street': '82 WILDFLOWER DR',
#   'city': 'Galt',
#   'zip': '95632',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 117.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 209347,
#   'latitude': 38.259708,
#   'longitude': -121.311616},
#  {'street': '8652 BANTON CIR',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 161.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 211500,
#   'latitude': 38.444,
#   'longitude': -121.370993},
#  {'street': '8428 MISTY PASS WAY',
#   'city': 'Antelope',
#   'zip': '95843',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 140.9,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 212000,
#   'latitude': 38.722959,
#   'longitude': -121.347115},
#  {'street': '7958 ROSEVIEW WAY',
#   'city': 'Sacramento',
#   'zip': '95828',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 134.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 213000,
#   'latitude': 38.467836,
#   'longitude': -121.410366},
#  {'street': '9020 LUKEN CT',
#   'city': 'Elk Grove',
#   'zip': '95624',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 131.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 216000,
#   'latitude': 38.451398,
#   'longitude': -121.366614},
#  {'street': '7809 VALLECITOS WAY',
#   'city': 'Sacramento',
#   'zip': '95828',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 82.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 216021,
#   'latitude': 38.508217,
#   'longitude': -121.411207},
#  {'street': '8445 OLD AUBURN RD',
#   'city': 'Citrus Heights',
#   'zip': '95610',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 174.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 219000,
#   'latitude': 38.715423,
#   'longitude': -121.246743},
#  {'street': '10085 ATKINS DR',
#   'city': 'Elk Grove',
#   'zip': '95757',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 121.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 219794,
#   'latitude': 38.390893,
#   'longitude': -121.437821},
#  {'street': '9185 CERROLINDA CIR',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 131.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 220000,
#   'latitude': 38.424497,
#   'longitude': -121.426595},
#  {'street': '9197 CORTINA CIR',
#   'city': 'Roseville',
#   'zip': '95678',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 0.0,
#   'type': 'Condo',
#   'sale_date': '2008-05-15',
#   'price': 220000,
#   'latitude': 38.793152,
#   'longitude': -121.290025},
#  {'street': '5429 HESPER WAY',
#   'city': 'Carmichael',
#   'zip': '95608',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 122.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 220000,
#   'latitude': 38.665104,
#   'longitude': -121.315901},
#  {'street': '1178 WARMWOOD CT',
#   'city': 'Galt',
#   'zip': '95632',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 164.4,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 220000,
#   'latitude': 38.289544,
#   'longitude': -121.284607},
#  {'street': '4900 ELUDE CT',
#   'city': 'Sacramento',
#   'zip': '95842',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 151.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 223000,
#   'latitude': 38.69674,
#   'longitude': -121.350519},
#  {'street': '3557 SODA WAY',
#   'city': 'Sacramento',
#   'zip': '95834',
#   'state': 'CA',
#   'beds': 0,
#   'baths': 0,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 224000,
#   'latitude': 38.631026,
#   'longitude': -121.501879},
#  {'street': '3528 SAINT GEORGE DR',
#   'city': 'Sacramento',
#   'zip': '95821',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 96.6,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 224000,
#   'latitude': 38.629468,
#   'longitude': -121.376445},
#  {'street': '7381 WASHBURN WAY',
#   'city': 'North Highlands',
#   'zip': '95660',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 89.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 224252,
#   'latitude': 38.70355,
#   'longitude': -121.375103},
#  {'street': '2181 WINTERHAVEN CIR',
#   'city': 'Cameron Park',
#   'zip': '95682',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 0.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 224500,
#   'latitude': 38.69757,
#   'longitude': -120.995739},
#  {'street': '7540 HICKORY AVE',
#   'city': 'Orangevale',
#   'zip': '95662',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 1,
#   'sq_m': 135.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 225000,
#   'latitude': 38.703056,
#   'longitude': -121.235221},
#  {'street': '5024 CHAMBERLIN CIR',
#   'city': 'Elk Grove',
#   'zip': '95757',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 134.7,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 228000,
#   'latitude': 38.389756,
#   'longitude': -121.446246},
#  {'street': '2400 INVERNESS DR',
#   'city': 'Lincoln',
#   'zip': '95648',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 126.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 229027,
#   'latitude': 38.897814,
#   'longitude': -121.324691},
#  {'street': '5 BISHOPGATE CT',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 123.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 229500,
#   'latitude': 38.467936,
#   'longitude': -121.445477},
#  {'street': '5601 REXLEIGH DR',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 159.3,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 230000,
#   'latitude': 38.445342,
#   'longitude': -121.441504},
#  {'street': '1909 YARNELL WAY',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 117.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 230000,
#   'latitude': 38.417382,
#   'longitude': -121.484325},
#  {'street': '9169 GARLINGTON CT',
#   'city': 'Sacramento',
#   'zip': '95829',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 3,
#   'sq_m': 211.8,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 232425,
#   'latitude': 38.457679,
#   'longitude': -121.35962},
#  {'street': '6932 RUSKUT WAY',
#   'city': 'Sacramento',
#   'zip': '95823',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 137.2,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 234000,
#   'latitude': 38.499893,
#   'longitude': -121.45889},
#  {'street': '7933 DAFFODIL WAY',
#   'city': 'Citrus Heights',
#   'zip': '95610',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 113.0,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 235000,
#   'latitude': 38.708824,
#   'longitude': -121.256803},
#  {'street': '8304 RED FOX WAY',
#   'city': 'Elk Grove',
#   'zip': '95758',
#   'state': 'CA',
#   'beds': 4,
#   'baths': 2,
#   'sq_m': 156.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 235301,
#   'latitude': 38.417,
#   'longitude': -121.397424},
#  {'street': '3882 YELLOWSTONE LN',
#   'city': 'El Dorado Hills',
#   'zip': '95762',
#   'state': 'CA',
#   'beds': 3,
#   'baths': 2,
#   'sq_m': 126.5,
#   'type': 'Residential',
#   'sale_date': '2008-05-15',
#   'price': 235738,
#   'latitude': 38.655245,
#   'longitude': -121.075915}]

# %% [markdown]
# Homework: Export as csv
