# %%
print('meow')
# Out:
# meow

# %%
print('hello hello')
# Out:
# hello hello

# %%
cl()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b4141a02c372> in <module>
# ----> 1 cl()
#
# NameError: name 'cl' is not defined

# %%
cp()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-97dd72a133c6> in <module>
# ----> 1 cp()
#
# NameError: name 'cp' is not defined
