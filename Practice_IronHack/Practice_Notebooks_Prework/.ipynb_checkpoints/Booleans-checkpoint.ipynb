# %%
type(False)
# Out:
# bool

# %%
1 > 2
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
'fox' == 'fox'
# Out:
# True

# %%
'fox' == 'raccoon'
# Out:
# False

# %%
b = None

# %%
b

# %%
set([1,1,2,3,4])
# Out:
# {1, 2, 3, 4}

# %%
#
