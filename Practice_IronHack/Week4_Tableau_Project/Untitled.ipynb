# %%
import pandas as pd 
import numpy as np
import matplotlib

# %%
data = pd.read_csv('WtoData_Tableau.csv')

# %%
data = data.drop([0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-34479412c374> in <module>
# ----> 1 data = data.drop([0])
#
# ~\anaconda3\envs\boogie_woogie\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\anaconda3\envs\boogie_woogie\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
data
# Out:
#               Indicator  \
# 1     Reporting Economy
# 2                 World
# 3                 World
# 4                 World
# 5                 World
# ...                 ...
# 6022             Zambia
# 6023           Zimbabwe
# 6024           Zimbabwe
# 6025           Zimbabwe
# 6026           Zimbabwe
#
#        Merchandise exports by product group and destination – annual (Million US dollar)  \
# 1                                        Product/Sector
# 2                  SI3_AGG - AG - Agricultural products
# 3                                 SI3_AGG - AGFO - Food
# 4                           SI3_AGG - MA - Manufactures
# 5                            SI3_AGG - MACH - Chemicals
# ...                                                 ...
# 6022                         SI3_AGG - MACH - Chemicals
# 6023               SI3_AGG - AG - Agricultural products
# 6024                              SI3_AGG - AGFO - Food
# 6025                        SI3_AGG - MA - Manufactures
# ...

# %%
data = data.transpose()

# %%
data.head(30)
# Out:
#                                                                  1     \
# Indicator                                           Reporting Economy
#   Merchandise exports by product group and dest...     Product/Sector
# Unnamed: 2                                            Partner Economy
# Unnamed: 3                                                       1998
# Unnamed: 4                                                       1999
# Unnamed: 5                                                       2000
# Unnamed: 6                                                       2001
# Unnamed: 7                                                       2002
# Unnamed: 8                                                       2003
# Unnamed: 9                                                       2004
# Unnamed: 10                                                      2005
# Unnamed: 11                                                      2006
# ...

# %%
data[data['Mexico']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\boogie_woogie\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Mexico'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-c0c879f70ac5> in <module>
# ----> 1 data[data['Mexico']]
#
# ~\anaconda3\envs\boogie_woogie\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
# ...

# %%
try_out
# Out:
#                                                                1     \
#   Merchandise exports by product group and dest...   Product/Sector
# Unnamed: 2                                          Partner Economy
# Unnamed: 3                                                     1998
# Unnamed: 4                                                     1999
# Unnamed: 5                                                     2000
# Unnamed: 6                                                     2001
# Unnamed: 7                                                     2002
# Unnamed: 8                                                     2003
# Unnamed: 9                                                     2004
# Unnamed: 10                                                    2005
# Unnamed: 11                                                    2006
# Unnamed: 12                                                    2007
# Unnamed: 13                                                    2008
# ...
