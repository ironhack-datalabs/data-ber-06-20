# %%
import pandas as pd 
import numpy as np
import matplotlib

# %%
data = pd.read_csv('Factbook_OECD.csv')

# %%
data.head(10)
# Out:
#             SUB                             Subject LOCATION    Country   YEA  \
# 0  PRODINCOM_G1                 GDP per hour worked      AUS  Australia  2011
# 1  PRODINCOM_G1                 GDP per hour worked      AUS  Australia  2012
# 2  PRODINCOM_G1                 GDP per hour worked      AUS  Australia  2013
# 3  PRODINCOM_G1                 GDP per hour worked      AUS  Australia  2014
# 4  PRODINCOM_G1                 GDP per hour worked      AUS  Australia  2015
# 5     AIRQTY_T1  CO? emissions from fuel combustion      AUS  Australia  2011
# 6     AIRQTY_T1  CO? emissions from fuel combustion      AUS  Australia  2012
# 7     AIRQTY_T1  CO? emissions from fuel combustion      AUS  Australia  2013
# 8     AIRQTY_T1  CO? emissions from fuel combustion      AUS  Australia  2014
# 9     AIRQTY_T1  CO? emissions from fuel combustion      AUS  Australia  2015
#
#    Year Unit Code       Unit  PowerCode Code PowerCode Reference Period Code  \
# ...

# %%
cols_null = data.isnull().sum()

# %%
cols_null
# Out:
# SUB                          0
# Subject                      0
# LOCATION                     0
# Country                      0
# YEA                          0
# Year                         0
# Unit Code                    0
# Unit                         0
# PowerCode Code               0
# PowerCode                    0
# Reference Period Code    34189
# Reference Period         34189
# Value                        0
# Flag Codes               34346
# Flags                    34346
# dtype: int64

# %%
drop_cols = list(cols_null[cols_null>30000].index)

# %%
drop_cols
# Out:
# ['Reference Period Code', 'Reference Period', 'Flag Codes', 'Flags']

# %%
data = data.drop(drop_cols, axis=1)

# %%
data
# Out:
#                 SUB                      Subject LOCATION    Country   YEA  \
# 0      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2011
# 1      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2012
# 2      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2013
# 3      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2014
# 4      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2015
# ...             ...                          ...      ...        ...   ...
# 35064     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2011
# 35065     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2012
# 35066     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2013
# 35067     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2014
# 35068     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2015
#
# ...

# %%
data = data.drop('YEA', axis= 1)

# %%
data
# Out:
#                 SUB                      Subject LOCATION    Country  Year  \
# 0      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2011
# 1      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2012
# 2      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2013
# 3      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2014
# 4      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2015
# ...             ...                          ...      ...        ...   ...
# 35064     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2011
# 35065     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2012
# 35066     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2013
# 35067     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2014
# 35068     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2015
#
#       Unit Code        Unit  PowerCode Code PowerCode      Value
# ...

# %%
data.rename(columns={'PowerCode Code': 'Power Code'}, inplace=True)

# %%
data.rename(columns={'LOCATION': 'Location', 'PowerCode': 'Power Code', 'SUB': 'Sub'}, inplace=True)

# %%
data
# Out:
#                 Sub                      Subject Location    Country  Year  \
# 0      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2011
# 1      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2012
# 2      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2013
# 3      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2014
# 4      PRODINCOM_G1          GDP per hour worked      AUS  Australia  2015
# ...             ...                          ...      ...        ...   ...
# 35064     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2011
# 35065     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2012
# 35066     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2013
# 35067     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2014
# 35068     TAXAPW_T1  Taxes on the average worker      LTU  Lithuania  2015
#
# ...

# %%
data.to_csv('Cleaner_Oecd.csv', index=False)

# %%
second_data = pd.read_csv('OECD_moredata.csv')

# %%
second_data.head(40)
# Out:
#    LOCATION    Country VARIABLE  \
# 0       AUS  Australia   CBGDPR
# 1       AUS  Australia   CBGDPR
# 2       AUS  Australia   CBGDPR
# 3       AUS  Australia   CBGDPR
# 4       AUS  Australia   CBGDPR
# 5       AUS  Australia   CBGDPR
# 6       AUS  Australia   CBGDPR
# 7       AUS  Australia   CBGDPR
# 8       AUS  Australia   CBGDPR
# 9       AUS  Australia   CBGDPR
# 10      AUS  Australia   CBGDPR
# 11      AUS  Australia   CBGDPR
# 12      AUS  Australia   CBGDPR
# 13      AUS  Australia   EXCHUD
# 14      AUS  Australia   EXCHUD
# 15      AUS  Australia   EXCHUD
# 16      AUS  Australia   EXCHUD
# 17      AUS  Australia   EXCHUD
# 18      AUS  Australia   EXCHUD
# 19      AUS  Australia   EXCHUD
# 20      AUS  Australia   EXCHUD
# 21      AUS  Australia   EXCHUD
# 22      AUS  Australia   EXCHUD
# 23      AUS  Australia   EXCHUD
# 24      AUS  Australia   EXCHUD
# 25      AUS  Australia   EXCHUD
# 26      AUS  Australia    MGSVD
# 27      AUS  Australia    MGSVD
# ...

# %%
second_data[['Time']].max()
# Out:
# Time    2019
# dtype: int64

# %%
nullCols = second_data.isnull().sum()

# %%
nullCols
# Out:
# LOCATION                     0
# Country                      0
# VARIABLE                     0
# Variable                     0
# FREQUENCY                    0
# Frequency                    0
# TIME                         0
# Time                         0
# Unit Code                    0
# Unit                         0
# PowerCode Code               0
# PowerCode                    0
# Reference Period Code     6559
# Reference Period          6559
# Value                        0
# Flag Codes               20352
# Flags                    20352
# dtype: int64

# %%
second_data['Flag Codes']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 20347   NaN
# 20348   NaN
# 20349   NaN
# 20350   NaN
# 20351   NaN
# Name: Flag Codes, Length: 20352, dtype: float64

# %%
6559/35069
# Out:
# 0.18703128118851406

# %%
20352/35069
# Out:
# 0.5803416122501355

# %%
nullCols = list(nullCols[nullCols > 20000].index)

# %%
second_data = second_data.drop(nullCols, axis=1)

# %%
second_data = second_data.drop('LOCATION', axis=1)

# %%
second_data[['FREQUENCY']].head(100)
# Out:
#    FREQUENCY
# 0          A
# 1          A
# 2          A
# 3          A
# 4          A
# ..       ...
# 95         A
# 96         A
# 97         A
# 98         A
# 99         A
#
# [100 rows x 1 columns]

# %%
second_data = second_data.drop('FREQUENCY', axis=1)

# %%
second_data = second_data.drop('VARIABLE', axis=1)

# %%
second_data.to_csv('OECD_vars_2007_2019.csv', index=False)

# %%
second_data.rename(columns={'TIME':'Year'}, inplace=True)

# %%
second_data = second_data.drop('PowerCode Code', axis=1)

# %%
second_data.to_csv('OECD_vars_2017_2019.csv', index=False)

# %%
third_data = pd.read_csv('OECD_vars_2007_2019.csv')

# %%
third_data.rename(columns={'TIME':'Year'}, inplace=True)

# %%
third_data=third_data.drop('PowerCode Code', axis=1)

# %%
third_data = third_data.drop('Frequency', axis=1)

# %%
third_data = third_data.drop('Unit Code', axis=1)

# %%
third_data = third_data.drop('Reference Period Code', axis=1)

# %%
third_data['Reference Period'].isnull().sum()
# Out:
# 6559

# %%
len(third_data)
# Out:
# 20352

# %%
6559/20352
# Out:
# 0.32227790880503143

# %%
third_data
# Out:
#          Country                                           Variable  Year  \
# 0      Australia     Current account balance as a percentage of GDP  2007
# 1      Australia     Current account balance as a percentage of GDP  2008
# 2      Australia     Current account balance as a percentage of GDP  2009
# 3      Australia     Current account balance as a percentage of GDP  2010
# 4      Australia     Current account balance as a percentage of GDP  2011
# ...          ...                                                ...   ...
# 20347   Colombia  Gross domestic product, volume in USD, at cons...  2015
# 20348   Colombia  Gross domestic product, volume in USD, at cons...  2016
# 20349   Colombia  Gross domestic product, volume in USD, at cons...  2017
# 20350   Colombia  Gross domestic product, volume in USD, at cons...  2018
# 20351   Colombia  Gross domestic product, volume in USD, at cons...  2019
#
#              Unit PowerCode Reference Period         Value
# ...

# %%
experiment = third_data.transpose()

# %%
experiment.head(10)
# Out:
#                                                            0      \
# Country                                                Australia
# Variable          Current account balance as a percentage of GDP
# Year                                                        2007
# Unit                                                  Percentage
# PowerCode                                                  Units
# Reference Period                                             NaN
# Value                                                   -6.74516
#
#                                                            1      \
# Country                                                Australia
# Variable          Current account balance as a percentage of GDP
# Year                                                        2008
# Unit                                                  Percentage
# PowerCode                                                  Units
# ...

# %%
third_data.to_csv('experiment_OECD_SQL.csv', index=False)
