# %%
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns 
import re

# %%
data_movies = pd.read_csv('./IMDb_data/IMDb_movies.csv')

# %%
data_actors = pd.read_csv('./IMDb_data/IMDb_names.csv')

# %%
data_ratings = pd.read_csv('./IMDb_data/IMDb_ratings.csv')

# %%
data_titles = pd.read_csv('./IMDb_data/IMDb_title_principals.csv')

# %%
data_movies.head(5)
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000574                        The Story of the Kelly Gang
# 1     tt0001892                                     Den sorte drøm
# 2     tt0002101                                          Cleopatra
# 3     tt0002130                                          L'Inferno
# 4     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
#
#                                       original_title  year date_published  \
# 0                        The Story of the Kelly Gang  1906     1906-12-26
# 1                                     Den sorte drøm  1911     1911-08-19
# 2                                          Cleopatra  1912     1912-11-13
# 3                                          L'Inferno  1911     1911-03-06
# 4  From the Manger to the Cross; or, Jesus of Naz...  1912           1913
#
#                        genre  duration           country language  \
# 0    Biography, Crime, Drama        70         Australia      NaN
# 1                      Drama        53  Germany, Denmark      NaN
# 2             Drama, History       100               USA  English
# 3  Adventure, Drama, Fantasy        68             Italy  Italian
# 4           Biography, Drama        60               USA  English
#
#                               director  ...  \
# 0                         Charles Tait  ...
# 1                            Urban Gad  ...
# 2                   Charles L. Gaskill  ...
# 3  Francesco Bertolini, Adolfo Padovan  ...
# 4                        Sidney Olcott  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 3  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# 4  R. Henderson Bland, Percy Dyer, Gene Gauntier,...
#
#                                          description avg_vote votes   budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537   $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171      NaN
# 2  The fabled queen of Egypt's affair with Roman ...      5.2   420  $ 45000
# 3  Loosely adapted from Dante's Divine Comedy and...      7.0  2019      NaN
# 4  An account of the life of Jesus Christ, based ...      5.7   438      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                7.0
# 1               NaN                   NaN       NaN                4.0
# 2               NaN                   NaN       NaN               24.0
# 3               NaN                   NaN       NaN               28.0
# 4               NaN                   NaN       NaN               12.0
#
#    reviews_from_critics
# 0                   7.0
# 1                   2.0
# 2                   3.0
# 3                  14.0
# 4                   5.0
#
# [5 rows x 22 columns]

# %%
data_movies.dtypes
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                       int64
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# dtype: object

# %%
data_movies.count().tail()
# Out:
# usa_gross_income         15094
# worlwide_gross_income    29892
# metascore                12722
# reviews_from_users       74196
# reviews_from_critics     70286
# dtype: int64

# %%
((data_movies.isna().sum())/len(data_movies)*100).round(2)
# Out:
# imdb_title_id             0.00
# title                     0.00
# original_title            0.00
# year                      0.00
# date_published            0.00
# genre                     0.00
# duration                  0.00
# country                   0.05
# language                  0.93
# director                  0.09
# writer                    1.84
# production_company        5.32
# actors                    0.08
# description               2.99
# avg_vote                  0.00
# votes                     0.00
# budget                   71.94
# usa_gross_income         81.43
# worlwide_gross_income    63.22
# metascore                84.35
# reviews_from_users        8.71
# reviews_from_critics     13.52
# dtype: float64

# %%
#data_movies.loc[data_movies['usa_gross_income'] > 0
data_movies[(data_movies['usa_gross_income'].isnull())]
# Out:
#       imdb_title_id                                              title  \
# 0         tt0000574                        The Story of the Kelly Gang
# 1         tt0001892                                     Den sorte drøm
# 2         tt0002101                                          Cleopatra
# 3         tt0002130                                          L'Inferno
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# ...             ...                                                ...
# 81268     tt9903716                                             Jessie
# 81269     tt9905412                                              Ottam
# 81270     tt9905462                                          Pengalila
# 81271     tt9911774                          Padmavyuhathile Abhimanyu
# 81272     tt9914286                                  Sokagin Çocuklari
#
#                                           original_title  year date_published  \
# 0                            The Story of the Kelly Gang  1906     1906-12-26
# 1                                         Den sorte drøm  1911     1911-08-19
# 2                                              Cleopatra  1912     1912-11-13
# 3                                              L'Inferno  1911     1911-03-06
# 4      From the Manger to the Cross; or, Jesus of Naz...  1912           1913
# ...                                                  ...   ...            ...
# 81268                                             Jessie  2019     2019-03-15
# 81269                                              Ottam  2019     2019-03-08
# 81270                                          Pengalila  2019     2019-03-08
# 81271                          Padmavyuhathile Abhimanyu  2019     2019-03-08
# 81272                                  Sokagin Çocuklari  2019     2019-03-15
#
#                            genre  duration           country   language  \
# 0        Biography, Crime, Drama        70         Australia        NaN
# 1                          Drama        53  Germany, Denmark        NaN
# 2                 Drama, History       100               USA    English
# 3      Adventure, Drama, Fantasy        68             Italy    Italian
# 4               Biography, Drama        60               USA    English
# ...                          ...       ...               ...        ...
# 81268           Horror, Thriller       106             India     Telugu
# 81269                      Drama       120             India  Malayalam
# 81270                      Drama       111             India  Malayalam
# 81271                      Drama       130             India  Malayalam
# 81272              Drama, Family        98            Turkey    Turkish
#
#                                   director  ...  \
# 0                             Charles Tait  ...
# 1                                Urban Gad  ...
# 2                       Charles L. Gaskill  ...
# 3      Francesco Bertolini, Adolfo Padovan  ...
# 4                            Sidney Olcott  ...
# ...                                    ...  ...
# 81268                      Aswani Kumar V.  ...
# 81269                                  Zam  ...
# 81270                        T.V. Chandran  ...
# 81271                      Vineesh Aaradya  ...
# 81272                    Ahmet Faik Akinci  ...
#
#                                                   actors  \
# 0      Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1      Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2      Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 3      Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# 4      R. Henderson Bland, Percy Dyer, Gene Gauntier,...
# ...                                                  ...
# 81268  Sritha Chandana, Pavani Gangireddy, Abhinav Go...
# 81269  Nandu Anand, Roshan Ullas, Manikandan R. Achar...
# 81270  Lal, Akshara Kishor, Iniya, Narain, Renji Pani...
# 81271  Anoop Chandran, Indrans, Sona Nair, Simon Brit...
# 81272  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
#
#                                              description avg_vote votes  \
# 0      True story of notorious Australian outlaw Ned ...      6.1   537
# 1      Two men of high rank are both wooing the beaut...      5.9   171
# 2      The fabled queen of Egypt's affair with Roman ...      5.2   420
# 3      Loosely adapted from Dante's Divine Comedy and...      7.0  2019
# 4      An account of the life of Jesus Christ, based ...      5.7   438
# ...                                                  ...      ...   ...
# 81268  Set in an abandoned house, the film follows a ...      7.2   219
# 81269  Set in Trivandrum, the story of Ottam unfolds ...      7.8   510
# 81270  An unusual bond between a sixty year old Dalit...      8.4   604
# 81271                                                NaN      8.4   369
# 81272                                                NaN      7.2   190
#
#              budget  usa_gross_income worlwide_gross_income metascore  \
# 0            $ 2250               NaN                   NaN       NaN
# 1               NaN               NaN                   NaN       NaN
# 2           $ 45000               NaN                   NaN       NaN
# 3               NaN               NaN                   NaN       NaN
# 4               NaN               NaN                   NaN       NaN
# ...             ...               ...                   ...       ...
# 81268           NaN               NaN                   NaN       NaN
# 81269   INR 4000000               NaN                $ 4791       NaN
# 81270  INR 10000000               NaN                   NaN       NaN
# 81271           NaN               NaN                   NaN       NaN
# 81272           NaN               NaN                $ 2833       NaN
#
#       reviews_from_users  reviews_from_critics
# 0                    7.0                   7.0
# 1                    4.0                   2.0
# 2                   24.0                   3.0
# 3                   28.0                  14.0
# 4                   12.0                   5.0
# ...                  ...                   ...
# 81268               21.0                   NaN
# 81269                NaN                   NaN
# 81270                NaN                   NaN
# 81271                NaN                   NaN
# 81272                NaN                   NaN
#
# [66179 rows x 22 columns]

# %%
data_movies = data_movies.drop('metascore', axis=1)

# %%
data_movies['date_published'] = pd.to_datetime(data_movies['date_published'])

# %%
data_movies['reviews_from_users'] = data_movies['reviews_from_users'].fillna(0)
data_movies['reviews_from_users'] = data_movies['reviews_from_users'].astype(int) 
data_movies.dtypes
# Out:
# imdb_title_id                    object
# title                            object
# original_title                   object
# year                              int64
# date_published           datetime64[ns]
# genre                            object
# duration                          int64
# country                          object
# language                         object
# director                         object
# writer                           object
# production_company               object
# actors                           object
# description                      object
# avg_vote                        float64
# votes                             int64
# budget                           object
# usa_gross_income                 object
# worlwide_gross_income            object
# reviews_from_users                int32
# reviews_from_critics            float64
# dtype: object

# %%
data_movies['reviews_from_critics'] = data_movies['reviews_from_critics'].fillna(0)
data_movies['reviews_from_critics'] = data_movies['reviews_from_critics'].astype(int)

# %%
data_movies['usa_gross_income'] = data_movies['usa_gross_income'].fillna(0)

# %%
data_movies.dtypes
# Out:
# imdb_title_id                    object
# title                            object
# original_title                   object
# year                              int64
# date_published           datetime64[ns]
# genre                            object
# duration                          int64
# country                          object
# language                         object
# director                         object
# writer                           object
# production_company               object
# actors                           object
# description                      object
# avg_vote                        float64
# votes                             int64
# budget                           object
# usa_gross_income                 object
# worlwide_gross_income            object
# reviews_from_users                int32
# reviews_from_critics              int32
# dtype: object

# %%
dropped_cols_movies = ['worlwide_gross_income','budget','usa_gross_income']
data_movies.drop(dropped_cols_movies, axis=1, inplace=True)

# %%
#data_countries = data_movies.groupby(['country','year'].agg('count').reset_index())

# %%
data_movies_test = (data_movies.groupby(['year']).count()).reset_index()

# %%
data_movies_test
# Out:
#      year  imdb_title_id  title  original_title  date_published  genre  \
# 0    1906              1      1               1               1      1
# 1    1911              4      4               4               4      4
# 2    1912              5      5               5               5      5
# 3    1913             13     13              13              13     13
# 4    1914             21     21              21              21     21
# ..    ...            ...    ...             ...             ...    ...
# 105  2015           2903   2903            2903            2903   2903
# 106  2016           3033   3033            3033            3033   3033
# 107  2017           3106   3106            3106            3106   3106
# 108  2018           2880   2880            2880            2880   2880
# 109  2019           1567   1567            1567            1567   1567
#
#      duration  country  language  director  writer  production_company  \
# 0           1        1         0         1       1                   1
# 1           4        4         2         4       4                   3
# 2           5        5         4         5       5                   5
# 3          13       13        12        13      12                  12
# 4          21       21        21        21      20                  21
# ..        ...      ...       ...       ...     ...                 ...
# 105      2903     2896      2878      2898    2831                2716
# 106      3033     3029      2985      3025    2968                2843
# 107      3106     3101      3038      3099    3004                2886
# 108      2880     2873      2803      2875    2773                2713
# 109      1567     1558      1518      1564    1502                1469
#
#      actors  description  avg_vote  votes  reviews_from_users  \
# 0         1            1         1      1                   1
# 1         4            4         4      4                   4
# 2         5            5         5      5                   5
# 3        13           13        13     13                  13
# 4        21           21        21     21                  21
# ..      ...          ...       ...    ...                 ...
# 105    2901         2861      2903   2903                2903
# 106    3031         3002      3033   3033                3033
# 107    3100         3064      3106   3106                3106
# 108    2868         2838      2880   2880                2880
# 109    1564         1537      1567   1567                1567
#
#      reviews_from_critics
# 0                       1
# 1                       4
# 2                       5
# 3                      13
# 4                      21
# ..                    ...
# 105                  2903
# 106                  3033
# 107                  3106
# 108                  2880
# 109                  1567
#
# [110 rows x 18 columns]

# %%
sns.catplot(data=data_movies_test, 
            x='year',
            y='title',
            height = 20,
            aspect =20/20);

# %%
fig, ax = plt.subplots(figsize = (12,8))

sns.scatterplot(data=data_movies_test,
            x='year',
            y='title',
            color='crimson',
            s=100);

# %%
data_actors
# Out:
#        imdb_name_id                   name               birth_name  height  \
# 0         nm0000001           Fred Astaire  Frederic Austerlitz Jr.     177
# 1         nm0000002          Lauren Bacall        Betty Joan Perske     174
# 2         nm0000003        Brigitte Bardot          Brigitte Bardot     166
# 3         nm0000004           John Belushi        John Adam Belushi     173
# 4         nm0000005         Ingmar Bergman     Ernst Ingmar Bergman     179
# ...             ...                    ...                      ...     ...
# 175710    nm9991131  Charoen Kaithitisuwan    Charoen Kaithitisuwan       0
# 175711    nm9991653        Wojciech Rzehak          Wojciech Rzehak       0
# 175712    nm9992720       McMagic Cardenas         McMagic Cardenas       0
# 175713    nm9992840    Rashaduzzman Shohag      Rashaduzzman Shohag       0
# 175714    nm9992999         William Plyler           William Plyler       0
#
#                                                       bio  \
# 0       Fred Astaire was born in Omaha, Nebraska, to J...
# 1       Lauren Bacall was born Betty Joan Perske on Se...
# 2       Brigitte Bardot was born on September 28, 1934...
# 3       John Belushi was born in Chicago, Illinois, US...
# 4       Ernst Ingmar Bergman was born July 14, 1918, t...
# ...                                                   ...
# 175710                                                NaN
# 175711                                                NaN
# 175712  McMagic Cardenas is an actor, known for The Sy...
# 175713                                                NaN
# 175714  William Plyler is a producer and actor, known ...
#
#                                             birth_details  birth_year  \
# 0                    May 10, 1899 in Omaha, Nebraska, USA        1899
# 1       September 16, 1924 in The Bronx, New York City...        1924
# 2                     September 28, 1934 in Paris, France        1934
# 3              January 24, 1949 in Chicago, Illinois, USA        1949
# 4           July 14, 1918 in Uppsala, Uppsala län, Sweden        1918
# ...                                                   ...         ...
# 175710                                                NaN           0
# 175711                                                NaN           0
# 175712                                                NaN           0
# 175713                                                NaN           0
# 175714                                                NaN           0
#
#        date_of_birth                           place_of_birth  \
# 0         1899-05-10                     Omaha, Nebraska, USA
# 1         1924-09-16  The Bronx, New York City, New York, USA
# 2         1934-09-28                            Paris, France
# 3         1949-01-24                   Chicago, Illinois, USA
# 4         1918-07-14             Uppsala, Uppsala län, Sweden
# ...              ...                                      ...
# 175710           NaN                                      NaN
# 175711           NaN                                      NaN
# 175712           NaN                                      NaN
# 175713           NaN                                      NaN
# 175714           NaN                                      NaN
#
#                                             death_details  death_year  \
# 0       June 22, 1987 in Los Angeles, California, USA ...        1987
# 1       August 12, 2014 in New York City, New York, US...        2014
# 2                                                     NaN           0
# 3       March 5, 1982 in Hollywood, Los Angeles, Calif...        1982
# 4             July 30, 2007 in Fårö, Gotlands län, Sweden        2007
# ...                                                   ...         ...
# 175710                                                NaN           0
# 175711                                                NaN           0
# 175712                                                NaN           0
# 175713                                                NaN           0
# 175714                                                NaN           0
#
#        date_of_death                             place_of_death  \
# 0         1987-06-22             Los Angeles, California, USA
# 1         2014-08-12             New York City, New York, USA
# 2                NaN                                        NaN
# 3         1982-03-05  Hollywood, Los Angeles, California, USA
# 4         2007-07-30                 Fårö, Gotlands län, Sweden
# ...              ...                                        ...
# 175710           NaN                                        NaN
# 175711           NaN                                        NaN
# 175712           NaN                                        NaN
# 175713           NaN                                        NaN
# 175714           NaN                                        NaN
#
#                               reason_of_death  spouses  divorces  \
# 0                                   pneumonia        2         0
# 1                                      stroke        2         1
# 2                                         NaN        4         3
# 3       acute cocaine and heroin intoxication        1         0
# 4                                         NaN        5         4
# ...                                       ...      ...       ...
# 175710                                    NaN        0         0
# 175711                                    NaN        0         0
# 175712                                    NaN        0         0
# 175713                                    NaN        0         0
# 175714                                    NaN        0         0
#
#         spouses_with_children  children              primary_profession  \
# 0                           1         2  soundtrack,actor,miscellaneous
# 1                           2         3              actress,soundtrack
# 2                           1         1     actress,soundtrack,producer
# 3                           0         0         actor,writer,soundtrack
# 4                           5         8           writer,director,actor
# ...                       ...       ...                             ...
# 175710                      0         0      producer,script_department
# 175711                      0         0                          writer
# 175712                      0         0                           actor
# 175713                      0         0            editorial_department
# 175714                      0         0           producer,actor,writer
#
#                                known_for_titles
# 0       tt0050419,tt0053137,tt0072308,tt0043044
# 1       tt0037382,tt0038355,tt0117057,tt0071877
# 2       tt0054452,tt0059956,tt0057345,tt0049189
# 3       tt0078723,tt0072562,tt0080455,tt0077975
# 4       tt0050976,tt0083922,tt0069467,tt0050986
# ...                                         ...
# 175710                                tt7547814
# 175711                                      NaN
# 175712                                tt7233828
# 175713                      tt8735380,tt8709986
# 175714            tt9413640,tt8483220,tt3239442
#
# [175715 rows x 20 columns]

# %%
data_actors.dtypes
# Out:
# imdb_name_id             object
# name                     object
# birth_name               object
# height                    int32
# bio                      object
# birth_details            object
# birth_year                int32
# date_of_birth            object
# place_of_birth           object
# death_details            object
# death_year                int32
# date_of_death            object
# place_of_death           object
# reason_of_death          object
# spouses                   int64
# divorces                  int64
# spouses_with_children     int64
# children                  int64
# primary_profession       object
# known_for_titles         object
# dtype: object

# %%
data_actors['height'] = data_actors['height'].fillna(0)
data_actors['height'] = data_actors['height'].astype(int)

# %%
data_actors['death_year'] = data_actors['death_year'].fillna(0)
data_actors['death_year'] = data_actors['death_year'].astype(int)

# %%
data_actors['birth_year'] = data_actors['birth_year'].fillna(0)
data_actors['birth_year'] = data_actors['birth_year'].astype(int)

# %%
data_actors['date_of_birth'] = pd.to_datetime(data_actors['date_of_birth'], errors='coerce')
data_actors['date_of_death'] = pd.to_datetime(data_actors['date_of_death'], errors='coerce')

# %%
data_actors.dtypes
# Out:
# imdb_name_id                     object
# name                             object
# birth_name                       object
# height                            int32
# bio                              object
# birth_details                    object
# birth_year                        int32
# date_of_birth            datetime64[ns]
# place_of_birth                   object
# death_details                    object
# death_year                        int32
# date_of_death            datetime64[ns]
# place_of_death                   object
# reason_of_death                  object
# spouses                           int64
# divorces                          int64
# spouses_with_children             int64
# children                          int64
# primary_profession               object
# known_for_titles                 object
# dtype: object

# %%
data_actors.isnull().sum()/len(data_actors)*100
# Out:
# imdb_name_id              0.000000
# name                      0.000000
# birth_name                0.000000
# height                    0.000000
# bio                      30.095894
# birth_details            57.186922
# birth_year                0.000000
# date_of_birth            57.287084
# place_of_birth           59.524230
# death_details            84.712745
# death_year                0.000000
# date_of_death            84.735509
# place_of_death           85.751928
# reason_of_death          93.186694
# spouses                   0.000000
# divorces                  0.000000
# spouses_with_children     0.000000
# children                  0.000000
# primary_profession        0.212845
# known_for_titles          0.550323
# dtype: float64

# %%
drop_actors_cols = ['reason_of_death','place_of_death','date_of_death','death_details']
data_actors = data_actors.drop(drop_actors_cols, axis=1)

# %%
split_attempt = (data_actors['known_for_titles'].str.split(',', expand=True))
split_attempt
# Out:
#                 0          1          2          3     4
# 0       tt0050419  tt0053137  tt0072308  tt0043044  None
# 1       tt0037382  tt0038355  tt0117057  tt0071877  None
# 2       tt0054452  tt0059956  tt0057345  tt0049189  None
# 3       tt0078723  tt0072562  tt0080455  tt0077975  None
# 4       tt0050976  tt0083922  tt0069467  tt0050986  None
# ...           ...        ...        ...        ...   ...
# 175710  tt7547814       None       None       None  None
# 175711        NaN        NaN        NaN        NaN   NaN
# 175712  tt7233828       None       None       None  None
# 175713  tt8735380  tt8709986       None       None  None
# 175714  tt9413640  tt8483220  tt3239442       None  None
#
# [175715 rows x 5 columns]

# %%
split_attempt.isnull().sum()/len(split_attempt)*100
# Out:
# 0     0.550323
# 1     9.172808
# 2    14.356771
# 3    18.973907
# 4    99.997724
# dtype: float64

# %%
split_attempt.columns=['movie_1','movie_2','movie_3','movie_4','movie_5']

# %%
split_attempt.drop('movie_5', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-1831a80eb642> in <module>
# ----> 1 split_attempt.drop('movie_5', axis=1, inplace=True)
#       2 split_attempt
#
# ~\anaconda3\envs\boogie_woogie\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\anaconda3\envs\boogie_woogie\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\envs\boogie_woogie\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\anaconda3\envs\boogie_woogie\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5015         if mask.any():
#    5016             if errors != "ignore":
# -> 5017                 raise KeyError(f"{labels[mask]} not found in axis")
#    5018             indexer = indexer[~mask]
#    5019         return self.delete(indexer)
#
# KeyError: "['movie_5'] not found in axis"

# %%
split_attempt
# Out:
#           movie_1    movie_2    movie_3    movie_4
# 0       tt0050419  tt0053137  tt0072308  tt0043044
# 1       tt0037382  tt0038355  tt0117057  tt0071877
# 2       tt0054452  tt0059956  tt0057345  tt0049189
# 3       tt0078723  tt0072562  tt0080455  tt0077975
# 4       tt0050976  tt0083922  tt0069467  tt0050986
# ...           ...        ...        ...        ...
# 175710  tt7547814       None       None       None
# 175711        NaN        NaN        NaN        NaN
# 175712  tt7233828       None       None       None
# 175713  tt8735380  tt8709986       None       None
# 175714  tt9413640  tt8483220  tt3239442       None
#
# [175715 rows x 4 columns]

# %%
split_attempt.iloc[175711]
# Out:
# movie_1    NaN
# movie_2    NaN
# movie_3    NaN
# movie_4    NaN
# Name: 175711, dtype: object
