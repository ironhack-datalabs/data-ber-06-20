# %%
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_movies = pd.read_csv('./IMDb_data/IMDb_movies.csv')

# %%
data_actors = pd.read_csv('./IMDb_data/IMDb_names.csv')

# %%
data_ratings = pd.read_csv('./IMDb_data/IMDb_ratings.csv')

# %%
data_titles = pd.read_csv('./IMDb_data/IMDb_title_principals.csv')

# %%
data_movies.head(3)
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 1     tt0001892               Den sorte drøm               Den sorte drøm
# 2     tt0002101                    Cleopatra                    Cleopatra
#
#    year date_published                    genre  duration           country  \
# 0  1906     1906-12-26  Biography, Crime, Drama        70         Australia
# 1  1911     1911-08-19                    Drama        53  Germany, Denmark
# 2  1912     1912-11-13           Drama, History       100               USA
#
#   language            director  ...  \
# 0      NaN        Charles Tait  ...
# 1      NaN           Urban Gad  ...
# 2  English  Charles L. Gaskill  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
#
#                                          description avg_vote votes   budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537   $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171      NaN
# 2  The fabled queen of Egypt's affair with Roman ...      5.2   420  $ 45000
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                7.0
# 1               NaN                   NaN       NaN                4.0
# 2               NaN                   NaN       NaN               24.0
#
#    reviews_from_critics
# 0                   7.0
# 1                   2.0
# 2                   3.0
#
# [3 rows x 22 columns]

# %%
data_movies.dtypes
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                       int64
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# dtype: object

# %%
data_movies.count().tail()
# Out:
# usa_gross_income         15094
# worlwide_gross_income    29892
# metascore                12722
# reviews_from_users       74196
# reviews_from_critics     70286
# dtype: int64

# %%
((data_movies.isna().sum())/len(data_movies)*100).round(2)
# Out:
# imdb_title_id             0.00
# title                     0.00
# original_title            0.00
# year                      0.00
# date_published            0.00
# genre                     0.00
# duration                  0.00
# country                   0.05
# language                  0.93
# director                  0.09
# writer                    1.84
# production_company        5.32
# actors                    0.08
# description               2.99
# avg_vote                  0.00
# votes                     0.00
# budget                   71.94
# usa_gross_income         81.43
# worlwide_gross_income    63.22
# metascore                84.35
# reviews_from_users        8.71
# reviews_from_critics     13.52
# dtype: float64

# %%
#data_movies.loc[data_movies['usa_gross_income'] > 0
data_movies[(data_movies['usa_gross_income'].isnull())]
# Out:
#       imdb_title_id                                              title  \
# 0         tt0000574                        The Story of the Kelly Gang
# 1         tt0001892                                     Den sorte drøm
# 2         tt0002101                                          Cleopatra
# 3         tt0002130                                          L'Inferno
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# ...             ...                                                ...
# 81268     tt9903716                                             Jessie
# 81269     tt9905412                                              Ottam
# 81270     tt9905462                                          Pengalila
# 81271     tt9911774                          Padmavyuhathile Abhimanyu
# 81272     tt9914286                                  Sokagin Çocuklari
#
#                                           original_title  year date_published  \
# 0                            The Story of the Kelly Gang  1906     1906-12-26
# 1                                         Den sorte drøm  1911     1911-08-19
# 2                                              Cleopatra  1912     1912-11-13
# 3                                              L'Inferno  1911     1911-03-06
# 4      From the Manger to the Cross; or, Jesus of Naz...  1912           1913
# ...                                                  ...   ...            ...
# 81268                                             Jessie  2019     2019-03-15
# 81269                                              Ottam  2019     2019-03-08
# 81270                                          Pengalila  2019     2019-03-08
# 81271                          Padmavyuhathile Abhimanyu  2019     2019-03-08
# 81272                                  Sokagin Çocuklari  2019     2019-03-15
#
#                            genre  duration           country   language  \
# 0        Biography, Crime, Drama        70         Australia        NaN
# 1                          Drama        53  Germany, Denmark        NaN
# 2                 Drama, History       100               USA    English
# 3      Adventure, Drama, Fantasy        68             Italy    Italian
# 4               Biography, Drama        60               USA    English
# ...                          ...       ...               ...        ...
# 81268           Horror, Thriller       106             India     Telugu
# 81269                      Drama       120             India  Malayalam
# 81270                      Drama       111             India  Malayalam
# 81271                      Drama       130             India  Malayalam
# 81272              Drama, Family        98            Turkey    Turkish
#
#                                   director  ...  \
# 0                             Charles Tait  ...
# 1                                Urban Gad  ...
# 2                       Charles L. Gaskill  ...
# 3      Francesco Bertolini, Adolfo Padovan  ...
# 4                            Sidney Olcott  ...
# ...                                    ...  ...
# 81268                      Aswani Kumar V.  ...
# 81269                                  Zam  ...
# 81270                        T.V. Chandran  ...
# 81271                      Vineesh Aaradya  ...
# 81272                    Ahmet Faik Akinci  ...
#
#                                                   actors  \
# 0      Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1      Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2      Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 3      Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# 4      R. Henderson Bland, Percy Dyer, Gene Gauntier,...
# ...                                                  ...
# 81268  Sritha Chandana, Pavani Gangireddy, Abhinav Go...
# 81269  Nandu Anand, Roshan Ullas, Manikandan R. Achar...
# 81270  Lal, Akshara Kishor, Iniya, Narain, Renji Pani...
# 81271  Anoop Chandran, Indrans, Sona Nair, Simon Brit...
# 81272  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
#
#                                              description avg_vote votes  \
# 0      True story of notorious Australian outlaw Ned ...      6.1   537
# 1      Two men of high rank are both wooing the beaut...      5.9   171
# 2      The fabled queen of Egypt's affair with Roman ...      5.2   420
# 3      Loosely adapted from Dante's Divine Comedy and...      7.0  2019
# 4      An account of the life of Jesus Christ, based ...      5.7   438
# ...                                                  ...      ...   ...
# 81268  Set in an abandoned house, the film follows a ...      7.2   219
# 81269  Set in Trivandrum, the story of Ottam unfolds ...      7.8   510
# 81270  An unusual bond between a sixty year old Dalit...      8.4   604
# 81271                                                NaN      8.4   369
# 81272                                                NaN      7.2   190
#
#              budget  usa_gross_income worlwide_gross_income metascore  \
# 0            $ 2250               NaN                   NaN       NaN
# 1               NaN               NaN                   NaN       NaN
# 2           $ 45000               NaN                   NaN       NaN
# 3               NaN               NaN                   NaN       NaN
# 4               NaN               NaN                   NaN       NaN
# ...             ...               ...                   ...       ...
# 81268           NaN               NaN                   NaN       NaN
# 81269   INR 4000000               NaN                $ 4791       NaN
# 81270  INR 10000000               NaN                   NaN       NaN
# 81271           NaN               NaN                   NaN       NaN
# 81272           NaN               NaN                $ 2833       NaN
#
#       reviews_from_users  reviews_from_critics
# 0                    7.0                   7.0
# 1                    4.0                   2.0
# 2                   24.0                   3.0
# 3                   28.0                  14.0
# 4                   12.0                   5.0
# ...                  ...                   ...
# 81268               21.0                   NaN
# 81269                NaN                   NaN
# 81270                NaN                   NaN
# 81271                NaN                   NaN
# 81272                NaN                   NaN
#
# [66179 rows x 22 columns]

# %%
data_movies = data_movies.drop('metascore', axis=1)

# %%
data_movies['date_published'] = pd.to_datetime(data_movies['date_published'])

# %%
data_movies['reviews_from_users'] = data_movies['reviews_from_users'].fillna(0)
data_movies['reviews_from_users'] = data_movies['reviews_from_users'].astype(int) 
data_movies.dtypes
# Out:
# imdb_title_id                    object
# title                            object
# original_title                   object
# year                              int64
# date_published           datetime64[ns]
# genre                            object
# duration                          int64
# country                          object
# language                         object
# director                         object
# writer                           object
# production_company               object
# actors                           object
# description                      object
# avg_vote                        float64
# votes                             int64
# budget                           object
# usa_gross_income                 object
# worlwide_gross_income            object
# reviews_from_users                int32
# reviews_from_critics            float64
# dtype: object

# %%
data_movies['reviews_from_critics'] = data_movies['reviews_from_critics'].fillna(0)
data_movies['reviews_from_critics'] = data_movies['reviews_from_critics'].astype(int)

# %%
data_movies['usa_gross_income'] = data_movies['usa_gross_income'].fillna(0)

# %%
data_movies.dtypes
# Out:
# imdb_title_id                    object
# title                            object
# original_title                   object
# year                              int64
# date_published           datetime64[ns]
# genre                            object
# duration                          int64
# country                          object
# language                         object
# director                         object
# writer                           object
# production_company               object
# actors                           object
# description                      object
# avg_vote                        float64
# votes                             int64
# budget                           object
# usa_gross_income                 object
# worlwide_gross_income            object
# reviews_from_users                int32
# reviews_from_critics              int32
# dtype: object

# %%
dropped_cols_movies = ['worlwide_gross_income','budget','usa_gross_income']
data_movies.drop(dropped_cols_movies, axis=1, inplace=True)

# %%
data_movies_test= (data_movies.groupby(['year']).count()).reset_index()

# %%
data_movies_test
# Out:
#      year  imdb_title_id  title  original_title  date_published  genre  \
# 0    1906              1      1               1               1      1
# 1    1911              4      4               4               4      4
# 2    1912              5      5               5               5      5
# 3    1913             13     13              13              13     13
# 4    1914             21     21              21              21     21
# ..    ...            ...    ...             ...             ...    ...
# 105  2015           2903   2903            2903            2903   2903
# 106  2016           3033   3033            3033            3033   3033
# 107  2017           3106   3106            3106            3106   3106
# 108  2018           2880   2880            2880            2880   2880
# 109  2019           1567   1567            1567            1567   1567
#
#      duration  country  language  director  writer  production_company  \
# 0           1        1         0         1       1                   1
# 1           4        4         2         4       4                   3
# 2           5        5         4         5       5                   5
# 3          13       13        12        13      12                  12
# 4          21       21        21        21      20                  21
# ..        ...      ...       ...       ...     ...                 ...
# 105      2903     2896      2878      2898    2831                2716
# 106      3033     3029      2985      3025    2968                2843
# 107      3106     3101      3038      3099    3004                2886
# 108      2880     2873      2803      2875    2773                2713
# 109      1567     1558      1518      1564    1502                1469
#
#      actors  description  avg_vote  votes  reviews_from_users  \
# 0         1            1         1      1                   1
# 1         4            4         4      4                   4
# 2         5            5         5      5                   5
# 3        13           13        13     13                  13
# 4        21           21        21     21                  21
# ..      ...          ...       ...    ...                 ...
# 105    2901         2861      2903   2903                2903
# 106    3031         3002      3033   3033                3033
# 107    3100         3064      3106   3106                3106
# 108    2868         2838      2880   2880                2880
# 109    1564         1537      1567   1567                1567
#
#      reviews_from_critics
# 0                       1
# 1                       4
# 2                       5
# 3                      13
# 4                      21
# ..                    ...
# 105                  2903
# 106                  3033
# 107                  3106
# 108                  2880
# 109                  1567
#
# [110 rows x 18 columns]

# %%
sns.catplot(data=data_movies_test, 
            x='year',
            y='title',
            height = 20,
            aspect =20/20);

# %%
fig, ax = plt.subplots(figsize = (12,8))

sns.scatterplot(data=data_movies_test,
            x='year',
            y='title',
            color='pink',
            s=100);

# %%
data_actors.dtypes
# Out:
# imdb_name_id              object
# name                      object
# birth_name                object
# height                   float64
# bio                       object
# birth_details             object
# birth_year               float64
# date_of_birth             object
# place_of_birth            object
# death_details             object
# death_year               float64
# date_of_death             object
# place_of_death            object
# reason_of_death           object
# spouses                    int64
# divorces                   int64
# spouses_with_children      int64
# children                   int64
# primary_profession        object
# known_for_titles          object
# dtype: object

# %%
data_actors['height'] = data_actors['height'].fillna(0)
data_actors['height'] = data_actors['height'].astype(int)

# %%
data_actors['death_year'] = data_actors['death_year'].fillna(0)
data_actors['death_year'] = data_actors['death_year'].astype(int)

# %%
data_actors['birth_year'] = data_actors['birth_year'].fillna(0)
data_actors['birth_year'] = data_actors['birth_year'].astype(int)

# %%
data_actors['date_of_birth'] = pd.to_datetime(data_actors['date_of_birth'], errors='coerce')
data_actors['date_of_death'] = pd.to_datetime(data_actors['date_of_death'], errors='coerce')

# %%
data_actors.head(3)
# Out:
#   imdb_name_id             name               birth_name  height  \
# 0    nm0000001     Fred Astaire  Frederic Austerlitz Jr.     177
# 1    nm0000002    Lauren Bacall        Betty Joan Perske     174
# 2    nm0000003  Brigitte Bardot          Brigitte Bardot     166
#
#                                                  bio  \
# 0  Fred Astaire was born in Omaha, Nebraska, to J...
# 1  Lauren Bacall was born Betty Joan Perske on Se...
# 2  Brigitte Bardot was born on September 28, 1934...
#
#                                        birth_details  birth_year  \
# 0               May 10, 1899 in Omaha, Nebraska, USA        1899
# 1  September 16, 1924 in The Bronx, New York City...        1924
# 2                September 28, 1934 in Paris, France        1934
#
#   date_of_birth                           place_of_birth  \
# 0    1899-05-10                     Omaha, Nebraska, USA
# 1    1924-09-16  The Bronx, New York City, New York, USA
# 2    1934-09-28                            Paris, France
#
#                                        death_details  death_year  \
# 0  June 22, 1987 in Los Angeles, California, USA ...        1987
# 1  August 12, 2014 in New York City, New York, US...        2014
# 2                                                NaN           0
#
#   date_of_death                  place_of_death reason_of_death  spouses  \
# 0    1987-06-22  Los Angeles, California, USA         pneumonia        2
# 1    2014-08-12  New York City, New York, USA            stroke        2
# 2           NaT                             NaN             NaN        4
#
#    divorces  spouses_with_children  children              primary_profession  \
# 0         0                      1         2  soundtrack,actor,miscellaneous
# 1         1                      2         3              actress,soundtrack
# 2         3                      1         1     actress,soundtrack,producer
#
#                           known_for_titles
# 0  tt0050419,tt0053137,tt0072308,tt0043044
# 1  tt0037382,tt0038355,tt0117057,tt0071877
# 2  tt0054452,tt0059956,tt0057345,tt0049189

# %%
data_actors.isnull().sum()/len(data_actors)*100
# Out:
# imdb_name_id              0.000000
# name                      0.000000
# birth_name                0.000000
# height                    0.000000
# bio                      30.095894
# birth_details            57.186922
# birth_year                0.000000
# date_of_birth            57.287084
# place_of_birth           59.524230
# death_details            84.712745
# death_year                0.000000
# date_of_death            84.735509
# place_of_death           85.751928
# reason_of_death          93.186694
# spouses                   0.000000
# divorces                  0.000000
# spouses_with_children     0.000000
# children                  0.000000
# primary_profession        0.212845
# known_for_titles          0.550323
# dtype: float64

# %%
drop_actors_cols = ['reason_of_death','place_of_death','date_of_death','death_details']
data_actors = data_actors.drop(drop_actors_cols, axis=1)

# %%
drop_actors_more = ['spouses', 'divorces', 'spouses_with_children', 'children', 'bio', 'birth_name', 'birth_details']
data_actors = data_actors.drop(drop_actors_more, axis=1)

# %%
data_actors['known_for_titles'] = (data_actors['known_for_titles'].str.split(',', expand=True)).copy()
data_actors
# Out:
#        imdb_name_id                   name  height  birth_year date_of_birth  \
# 0         nm0000001           Fred Astaire     177        1899    1899-05-10
# 1         nm0000002          Lauren Bacall     174        1924    1924-09-16
# 2         nm0000003        Brigitte Bardot     166        1934    1934-09-28
# 3         nm0000004           John Belushi     173        1949    1949-01-24
# 4         nm0000005         Ingmar Bergman     179        1918    1918-07-14
# ...             ...                    ...     ...         ...           ...
# 175710    nm9991131  Charoen Kaithitisuwan       0           0           NaT
# 175711    nm9991653        Wojciech Rzehak       0           0           NaT
# 175712    nm9992720       McMagic Cardenas       0           0           NaT
# 175713    nm9992840    Rashaduzzman Shohag       0           0           NaT
# 175714    nm9992999         William Plyler       0           0           NaT
#
#                                  place_of_birth  death_year  \
# 0                          Omaha, Nebraska, USA        1987
# 1       The Bronx, New York City, New York, USA        2014
# 2                                 Paris, France           0
# 3                        Chicago, Illinois, USA        1982
# 4                  Uppsala, Uppsala län, Sweden        2007
# ...                                         ...         ...
# 175710                                      NaN           0
# 175711                                      NaN           0
# 175712                                      NaN           0
# 175713                                      NaN           0
# 175714                                      NaN           0
#
#                     primary_profession known_for_titles
# 0       soundtrack,actor,miscellaneous        tt0050419
# 1                   actress,soundtrack        tt0037382
# 2          actress,soundtrack,producer        tt0054452
# 3              actor,writer,soundtrack        tt0078723
# 4                writer,director,actor        tt0050976
# ...                                ...              ...
# 175710      producer,script_department        tt7547814
# 175711                          writer              NaN
# 175712                           actor        tt7233828
# 175713            editorial_department        tt8735380
# 175714           producer,actor,writer        tt9413640
#
# [175715 rows x 9 columns]

# %%
data_actors.isnull().sum()/len(data_actors)*100
# Out:
# imdb_name_id           0.000000
# name                   0.000000
# height                 0.000000
# birth_year             0.000000
# date_of_birth         57.287084
# place_of_birth        59.524230
# death_year             0.000000
# primary_profession     0.212845
# known_for_titles       0.550323
# dtype: float64

# %%
data_ratings
# Out:
#       imdb_title_id  weighted_average_vote  total_votes  mean_vote  \
# 0         tt0000574                    6.1          537        6.3
# 1         tt0001892                    5.9          171        6.1
# 2         tt0002101                    5.2          420        5.2
# 3         tt0002130                    7.0         2019        6.9
# 4         tt0002199                    5.7          438        5.8
# ...             ...                    ...          ...        ...
# 81268     tt9903716                    7.2          219        8.1
# 81269     tt9905412                    7.8          510        7.8
# 81270     tt9905462                    8.4          604        8.1
# 81271     tt9911774                    8.4          369        8.2
# 81272     tt9914286                    7.2          190        9.5
#
#        median_vote  votes_10  votes_9  votes_8  votes_7  votes_6  ...  \
# 0              6.0        54       17       55      121      122  ...
# 1              6.0         5        6       17       41       52  ...
# 2              5.0        12        8       16       60       89  ...
# 3              7.0       194      208      386      571      308  ...
# 4              6.0        28       15       42       75      114  ...
# ...            ...       ...      ...      ...      ...      ...  ...
# 81268          9.0        86       37       33       15       17  ...
# 81269          9.0       184       80       91       39       10  ...
# 81270          9.0       280       80      101       31        9  ...
# 81271          9.0       111       74       74       61       30  ...
# 81272         10.0       177        0        2        0        0  ...
#
#        females_30age_avg_vote  females_30age_votes  females_45age_avg_vote  \
# 0                         6.0                 19.0                     6.6
# 1                         5.8                  4.0                     6.5
# 2                         5.5                 14.0                     6.2
# 3                         7.3                 74.0                     7.4
# 4                         4.8                 10.0                     6.5
# ...                       ...                  ...                     ...
# 81268                     5.6                  6.0                     6.7
# 81269                     NaN                  NaN                     NaN
# 81270                     NaN                  NaN                     NaN
# 81271                     NaN                  NaN                     NaN
# 81272                     NaN                  NaN                     NaN
#
#        females_45age_votes  top1000_voters_rating  top1000_voters_votes  \
# 0                     14.0                    6.3                  64.0
# 1                      8.0                    5.9                  29.0
# 2                     20.0                    4.9                  57.0
# 3                     75.0                    7.0                 126.0
# 4                     15.0                    5.7                  56.0
# ...                    ...                    ...                   ...
# 81268                  3.0                    2.0                   4.0
# 81269                  NaN                    1.0                   1.0
# 81270                  NaN                    1.0                   1.0
# 81271                  NaN                    1.0                   1.0
# 81272                  NaN                    4.0                   3.0
#
#        us_voters_rating  us_voters_votes  non_us_voters_rating  \
# 0                   6.0             89.0                   6.2
# 1                   6.2             27.0                   6.0
# 2                   5.5            197.0                   4.7
# 3                   7.1            452.0                   7.0
# 4                   5.9            161.0                   5.7
# ...                 ...              ...                   ...
# 81268               5.0             14.0                   7.1
# 81269               NaN              NaN                   1.0
# 81270               NaN              NaN                   4.0
# 81271               NaN              NaN                   1.0
# 81272               1.7              5.0                   6.2
#
#        non_us_voters_votes
# 0                    309.0
# 1                    114.0
# 2                    103.0
# 3                   1076.0
# 4                    164.0
# ...                    ...
# 81268                 45.0
# 81269                  3.0
# 81270                  3.0
# 81271                  1.0
# 81272                  5.0
#
# [81273 rows x 49 columns]

# %%
data_ratings.dtypes
# Out:
# imdb_title_id                 object
# weighted_average_vote        float64
# total_votes                    int64
# mean_vote                    float64
# median_vote                  float64
# votes_10                       int64
# votes_9                        int64
# votes_8                        int64
# votes_7                        int64
# votes_6                        int64
# votes_5                        int64
# votes_4                        int64
# votes_3                        int64
# votes_2                        int64
# votes_1                        int64
# allgenders_0age_avg_vote     float64
# allgenders_0age_votes        float64
# allgenders_18age_avg_vote    float64
# allgenders_18age_votes       float64
# allgenders_30age_avg_vote    float64
# allgenders_30age_votes       float64
# allgenders_45age_avg_vote    float64
# allgenders_45age_votes       float64
# males_allages_avg_vote       float64
# males_allages_votes          float64
# males_0age_avg_vote          float64
# males_0age_votes             float64
# males_18age_avg_vote         float64
# males_18age_votes            float64
# males_30age_avg_vote         float64
# males_30age_votes            float64
# males_45age_avg_vote         float64
# males_45age_votes            float64
# females_allages_avg_vote     float64
# females_allages_votes        float64
# females_0age_avg_vote        float64
# females_0age_votes           float64
# females_18age_avg_vote       float64
# females_18age_votes          float64
# females_30age_avg_vote       float64
# females_30age_votes          float64
# females_45age_avg_vote       float64
# females_45age_votes          float64
# top1000_voters_rating        float64
# top1000_voters_votes         float64
# us_voters_rating             float64
# us_voters_votes              float64
# non_us_voters_rating         float64
# non_us_voters_votes          float64
# dtype: object

# %%
data_ratings.isnull().sum()/len(data_ratings)*100
# Out:
# imdb_title_id                 0.000000
# weighted_average_vote         0.000000
# total_votes                   0.000000
# mean_vote                     0.000000
# median_vote                   0.000000
# votes_10                      0.000000
# votes_9                       0.000000
# votes_8                       0.000000
# votes_7                       0.000000
# votes_6                       0.000000
# votes_5                       0.000000
# votes_4                       0.000000
# votes_3                       0.000000
# votes_2                       0.000000
# votes_1                       0.000000
# allgenders_0age_avg_vote     67.340937
# allgenders_0age_votes        67.340937
# allgenders_18age_avg_vote     0.510625
# allgenders_18age_votes        0.510625
# allgenders_30age_avg_vote     0.011074
# allgenders_30age_votes        0.011074
# allgenders_45age_avg_vote     0.139038
# allgenders_45age_votes        0.139038
# males_allages_avg_vote        0.001230
# males_allages_votes           0.001230
# males_0age_avg_vote          74.974469
# males_0age_votes             74.974469
# males_18age_avg_vote          1.299324
# males_18age_votes             1.299324
# males_30age_avg_vote          0.011074
# males_30age_votes             0.011074
# males_45age_avg_vote          0.188254
# males_45age_votes             0.188254
# females_allages_avg_vote      0.086129
# females_allages_votes         0.086129
# females_0age_avg_vote        81.133956
# females_0age_votes           81.133956
# females_18age_avg_vote        6.193939
# females_18age_votes           6.193939
# females_30age_avg_vote        1.063084
# females_30age_votes           1.063084
# females_45age_avg_vote        3.164643
# females_45age_votes           3.164643
# top1000_voters_rating         0.745635
# top1000_voters_votes          0.745635
# us_voters_rating              0.294071
# us_voters_votes               0.294071
# non_us_voters_rating          0.004922
# non_us_voters_votes           0.004922
# dtype: float64

# %%
drop_ratings_cols = ['allgenders_0age_avg_vote', 'allgenders_0age_votes', 'males_0age_avg_vote', 'males_0age_votes', 'females_0age_avg_vote', 'females_0age_votes']
data_ratings = data_ratings.drop(drop_ratings_cols, axis=1)

# %%
data_ratings
# Out:
#       imdb_title_id  weighted_average_vote  total_votes  mean_vote  \
# 0         tt0000574                    6.1          537        6.3
# 1         tt0001892                    5.9          171        6.1
# 2         tt0002101                    5.2          420        5.2
# 3         tt0002130                    7.0         2019        6.9
# 4         tt0002199                    5.7          438        5.8
# ...             ...                    ...          ...        ...
# 81268     tt9903716                    7.2          219        8.1
# 81269     tt9905412                    7.8          510        7.8
# 81270     tt9905462                    8.4          604        8.1
# 81271     tt9911774                    8.4          369        8.2
# 81272     tt9914286                    7.2          190        9.5
#
#        median_vote  votes_10  votes_9  votes_8  votes_7  votes_6  ...  \
# 0              6.0        54       17       55      121      122  ...
# 1              6.0         5        6       17       41       52  ...
# 2              5.0        12        8       16       60       89  ...
# 3              7.0       194      208      386      571      308  ...
# 4              6.0        28       15       42       75      114  ...
# ...            ...       ...      ...      ...      ...      ...  ...
# 81268          9.0        86       37       33       15       17  ...
# 81269          9.0       184       80       91       39       10  ...
# 81270          9.0       280       80      101       31        9  ...
# 81271          9.0       111       74       74       61       30  ...
# 81272         10.0       177        0        2        0        0  ...
#
#        females_30age_avg_vote  females_30age_votes  females_45age_avg_vote  \
# 0                         6.0                 19.0                     6.6
# 1                         5.8                  4.0                     6.5
# 2                         5.5                 14.0                     6.2
# 3                         7.3                 74.0                     7.4
# 4                         4.8                 10.0                     6.5
# ...                       ...                  ...                     ...
# 81268                     5.6                  6.0                     6.7
# 81269                     NaN                  NaN                     NaN
# 81270                     NaN                  NaN                     NaN
# 81271                     NaN                  NaN                     NaN
# 81272                     NaN                  NaN                     NaN
#
#        females_45age_votes  top1000_voters_rating  top1000_voters_votes  \
# 0                     14.0                    6.3                  64.0
# 1                      8.0                    5.9                  29.0
# 2                     20.0                    4.9                  57.0
# 3                     75.0                    7.0                 126.0
# 4                     15.0                    5.7                  56.0
# ...                    ...                    ...                   ...
# 81268                  3.0                    2.0                   4.0
# 81269                  NaN                    1.0                   1.0
# 81270                  NaN                    1.0                   1.0
# 81271                  NaN                    1.0                   1.0
# 81272                  NaN                    4.0                   3.0
#
#        us_voters_rating  us_voters_votes  non_us_voters_rating  \
# 0                   6.0             89.0                   6.2
# 1                   6.2             27.0                   6.0
# 2                   5.5            197.0                   4.7
# 3                   7.1            452.0                   7.0
# 4                   5.9            161.0                   5.7
# ...                 ...              ...                   ...
# 81268               5.0             14.0                   7.1
# 81269               NaN              NaN                   1.0
# 81270               NaN              NaN                   4.0
# 81271               NaN              NaN                   1.0
# 81272               1.7              5.0                   6.2
#
#        non_us_voters_votes
# 0                    309.0
# 1                    114.0
# 2                    103.0
# 3                   1076.0
# 4                    164.0
# ...                    ...
# 81268                 45.0
# 81269                  3.0
# 81270                  3.0
# 81271                  1.0
# 81272                  5.0
#
# [81273 rows x 43 columns]

# %%
data_ratings = data_ratings.apply(lambda x:x.fillna(0))

# %%
int_ratings = ['allgenders_18age_votes', 'allgenders_30age_votes', 'allgenders_45age_votes', 'males_allages_votes', 'males_18age_votes','males_30age_votes', 'males_45age_votes', 'females_allages_votes', 'females_18age_votes', 'females_30age_votes', 'females_45age_votes', 'top1000_voters_votes', 'us_voters_votes', 'non_us_voters_votes']

for col in int_ratings:
    data_ratings[col] = data_ratings[col].astype(int)

# %%
data_ratings.dtypes
# Out:
# imdb_title_id                 object
# weighted_average_vote        float64
# total_votes                    int64
# mean_vote                    float64
# median_vote                  float64
# votes_10                       int64
# votes_9                        int64
# votes_8                        int64
# votes_7                        int64
# votes_6                        int64
# votes_5                        int64
# votes_4                        int64
# votes_3                        int64
# votes_2                        int64
# votes_1                        int64
# allgenders_18age_avg_vote    float64
# allgenders_18age_votes         int32
# allgenders_30age_avg_vote    float64
# allgenders_30age_votes         int32
# allgenders_45age_avg_vote    float64
# allgenders_45age_votes         int32
# males_allages_avg_vote       float64
# males_allages_votes            int32
# males_18age_avg_vote         float64
# males_18age_votes              int32
# males_30age_avg_vote         float64
# males_30age_votes              int32
# males_45age_avg_vote         float64
# males_45age_votes              int32
# females_allages_avg_vote     float64
# females_allages_votes          int32
# females_18age_avg_vote       float64
# females_18age_votes            int32
# females_30age_avg_vote       float64
# females_30age_votes            int32
# females_45age_avg_vote       float64
# females_45age_votes            int32
# top1000_voters_rating        float64
# top1000_voters_votes           int32
# us_voters_rating             float64
# us_voters_votes                int32
# non_us_voters_rating         float64
# non_us_voters_votes            int32
# dtype: object

# %%
data_titles.head()
# Out:
#   imdb_title_id  ordering imdb_name_id  category  job         characters
# 0     tt0000574         1    nm0846887   actress  NaN     ["Kate Kelly"]
# 1     tt0000574         2    nm0846894     actor  NaN  ["School Master"]
# 2     tt0000574         3    nm3002376     actor  NaN     ["Steve Hart"]
# 3     tt0000574         4    nm0170118   actress  NaN                NaN
# 4     tt0000574         5    nm0846879  director  NaN                NaN

# %%
data_titles.isnull().sum()/len(data_titles)*100
# Out:
# imdb_title_id     0.000000
# ordering          0.000000
# imdb_name_id      0.000000
# category          0.000000
# job              74.384409
# characters       59.300036
# dtype: float64

# %%
drop_titles_cols = ['job', 'characters']
data_titles = data_titles.drop(drop_titles_cols, axis=1)

# %%
data_titles
# Out:
#        imdb_title_id  ordering imdb_name_id         category
# 0          tt0000574         1    nm0846887          actress
# 1          tt0000574         2    nm0846894            actor
# 2          tt0000574         3    nm3002376            actor
# 3          tt0000574         4    nm0170118          actress
# 4          tt0000574         5    nm0846879         director
# ...              ...       ...          ...              ...
# 377843     tt9903716         5   nm10532693         director
# 377844     tt9903716         6   nm10531260         producer
# 377845     tt9903716         7    nm6044359         composer
# 377846     tt9903716         8   nm10532695  cinematographer
# 377847     tt9903716         9    nm9492020           editor
#
# [377848 rows x 4 columns]

# %%
len(data_movies)/len(data_titles)*100
# Out:
# 21.509442950604477

# %%
len(data_actors)/len(data_titles)*100
# Out:
# 46.50414981685757

# %%
len(data_ratings)/len(data_titles)*100
# Out:
# 21.509442950604477

# %%
data_movies = data_movies.to_csv('data_movies_clean.csv', index=False)

# %%
data_titles = data_titles.to_csv('data_titles_clean.csv', index=False)

# %%
data_ratings = data_ratings.to_csv('data_ratings_clean.csv', index=False)

# %%
data_actors = data_actors.to_csv('data_actors_clean.csv', index=False)

# %%
data_movies = pd.read_csv('./Clean_Data_IMDB/data_movies_clean.csv')
data_titles = pd.read_csv('./Clean_Data_IMDB/data_titles_clean.csv')
data_ratings = pd.read_csv('./Clean_Data_IMDB/data_ratings_clean.csv')
data_actors = pd.read_csv('./Clean_Data_IMDB/data_actors_clean.csv')

# %%
#experiment_data = pd.merge(data_movies, data_titles, on='imdb_title_id', how='inner')
#experiment_data

# %%
data_actors.head(3)
# Out:
#   imdb_name_id             name  height  birth_year date_of_birth  \
# 0    nm0000001     Fred Astaire     177        1899    1899-05-10
# 1    nm0000002    Lauren Bacall     174        1924    1924-09-16
# 2    nm0000003  Brigitte Bardot     166        1934    1934-09-28
#
#                             place_of_birth  death_year  \
# 0                     Omaha, Nebraska, USA        1987
# 1  The Bronx, New York City, New York, USA        2014
# 2                            Paris, France           0
#
#                primary_profession known_for_titles
# 0  soundtrack,actor,miscellaneous        tt0050419
# 1              actress,soundtrack        tt0037382
# 2     actress,soundtrack,producer        tt0054452

# %%
data_titles.head(3)
# Out:
#   imdb_title_id  ordering imdb_name_id category
# 0     tt0000574         1    nm0846887  actress
# 1     tt0000574         2    nm0846894    actor
# 2     tt0000574         3    nm3002376    actor

# %%
data_movies.head(3)
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 1     tt0001892               Den sorte drøm               Den sorte drøm
# 2     tt0002101                    Cleopatra                    Cleopatra
#
#    year date_published                    genre  duration           country  \
# 0  1906     1906-12-26  Biography, Crime, Drama        70         Australia
# 1  1911     1911-08-19                    Drama        53  Germany, Denmark
# 2  1912     1912-11-13           Drama, History       100               USA
#
#   language            director                                 writer  \
# 0      NaN        Charles Tait                           Charles Tait
# 1      NaN           Urban Gad  Urban Gad, Gebhard Schätzler-Perasini
# 2  English  Charles L. Gaskill                       Victorien Sardou
#
#               production_company  \
# 0                 J. and N. Tait
# 1                       Fotorama
# 2  Helen Gardner Picture Players
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
#
#                                          description  avg_vote  votes  \
# 0  True story of notorious Australian outlaw Ned ...       6.1    537
# 1  Two men of high rank are both wooing the beaut...       5.9    171
# 2  The fabled queen of Egypt's affair with Roman ...       5.2    420
#
#    reviews_from_users  reviews_from_critics
# 0                   7                     7
# 1                   4                     2
# 2                  24                     3

# %%
data_movies_drop = ['original_title','actors', 'description']
data_movies = data_movies.drop(data_movies_drop, axis=1)

# %%
data_ratings.head(3)
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000574                    6.1          537        6.3          6.0
# 1     tt0001892                    5.9          171        6.1          6.0
# 2     tt0002101                    5.2          420        5.2          5.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        54       17       55      121      122  ...                     6.0
# 1         5        6       17       41       52  ...                     5.8
# 2        12        8       16       60       89  ...                     5.5
#
#    females_30age_votes  females_45age_avg_vote  females_45age_votes  \
# 0                   19                     6.6                   14
# 1                    4                     6.5                    8
# 2                   14                     6.2                   20
#
#    top1000_voters_rating  top1000_voters_votes  us_voters_rating  \
# 0                    6.3                    64               6.0
# 1                    5.9                    29               6.2
# 2                    4.9                    57               5.5
#
#    us_voters_votes  non_us_voters_rating  non_us_voters_votes
# 0               89                   6.2                  309
# 1               27                   6.0                  114
# 2              197                   4.7                  103
#
# [3 rows x 43 columns]

# %%
ratings_drop_cols = ['votes_10','votes_9','votes_8', 'votes_7','votes_6','votes_5','votes_4','votes_3','votes_2','votes_1']
data_ratings = data_ratings.drop(ratings_drop_cols, axis=1)

# %%
data_movies = data_movies.to_csv('data_movies_clean.csv', index=False)
data_ratings = data_ratings.to_csv('data_ratings_clean.csv', index=False)
